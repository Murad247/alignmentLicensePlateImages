# %% [markdown]
# # Код для разметки угловых точек номера

# %%
import cv2
import os
import glob
import tkinter as tk
from tkinter import filedialog
import shutil

class ImageMarker:
    def __init__(self):
        self.images = []
        self.current_image_index = 0
        self.points = []
        self.scale_factor = 3  # Увеличиваем изображение в 3 раза
        self.annotated_images = set()  # Set to store annotated image paths
        self.load_images()

    def load_images(self):
        root = tk.Tk()
        root.withdraw()
        folder_path = r'F:\grozny\labeling'

        if not folder_path:
            print("Папка не выбрана. Завершение программы.")
            return

        self.images = glob.glob(os.path.join(folder_path, '*.jpg')) + glob.glob(os.path.join(folder_path, '*.png'))
        self.images.sort()

        if not self.images:
            print(f"Не найдено изображений в папке: {folder_path}")
            return

        print(f"Найдено {len(self.images)} изображений в папке: {folder_path}")

        self.output_folder = r'F:\grozny\result'
        self.img_out = "img_out"
        if not self.output_folder:
            print("Папка для сохранения меток не выбрана. Завершение программы.")
            return

    def save_points(self):
        image_name = os.path.basename(self.images[self.current_image_index])
        txt_file_path = os.path.join(self.output_folder, f"{os.path.splitext(image_name)[0]}.txt")
        with open(txt_file_path, 'w') as file:
            for point in self.points:
                # Масштабируем координаты обратно перед сохранением
                original_point = (point[0] // self.scale_factor, point[1] // self.scale_factor)
                file.write(f"{original_point[0]}, {original_point[1]}\n")
        self.annotated_images.add(self.images[self.current_image_index])  # Add annotated image to set

    def click_event(self, event, x, y, flags, param):
        if event == cv2.EVENT_LBUTTONDOWN:
            if len(self.points) < 4:
                self.points.append((x, y))
                self.display_image()
            if len(self.points) == 4:
                self.save_points()

    def display_image(self):
        image = self.scaled_image.copy()
        for point in self.points:
            cv2.circle(image, point, 5, (0, 0, 255), -1)
            cv2.putText(image, f"{point}", point, cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1, cv2.LINE_AA)
        cv2.imshow("Image", image)

    def run(self):
        if not self.images or not self.output_folder:
            return

        cv2.namedWindow("Image")
        cv2.setMouseCallback("Image", self.click_event)

        while True:
            self.original_image = cv2.imread(self.images[self.current_image_index])
            # Масштабируем изображение
            width = int(self.original_image.shape[1] * self.scale_factor)
            height = int(self.original_image.shape[0] * self.scale_factor)
            self.scaled_image = cv2.resize(self.original_image, (width, height))
            self.points = []
            self.display_image()
            key = cv2.waitKey(0)

            if key == ord('d') and self.current_image_index < len(self.images) - 1:
                self.current_image_index += 1
            elif key == ord('a') and self.current_image_index > 0:
                self.current_image_index -= 1
            elif key == ord('p'):
                break

        # After marking session ends
        cv2.destroyAllWindows()

        # Move or delete annotated images
        for img_path in self.annotated_images:
            if os.path.exists(img_path):
                shutil.move(img_path, self.img_out)  # Move to output folder
            # Optionally delete the original image after moving
            # os.remove(img_path)

if __name__ == "__main__":
    ImageMarker().run()

# %% [markdown]
# # Код выравнивания изображений методом перспективного преобразования

# %% [markdown]
# ## Для выравнивания используются размеченные нами угловые точки номеров

# %%
import cv2
import numpy as np
import os

def load_corners_from_file(file_path):
    with open(file_path, 'r') as file:
        corners = []
        for line in file:
            x, y = map(float, line.strip().split(','))
            corners.append((x, y))
        return np.array(corners, dtype="float32")

def align_image(image, corners):
    # Упорядочивание угловых точек в порядке: верхний левый, верхний правый, нижний правый, нижний левый
    rect = np.zeros((4, 2), dtype="float32")
    s = corners.sum(axis=1)
    rect[0] = corners[np.argmin(s)]
    rect[2] = corners[np.argmax(s)]

    diff = np.diff(corners, axis=1)
    rect[1] = corners[np.argmin(diff)]
    rect[3] = corners[np.argmax(diff)]

    # Определение ширины и высоты нового изображения
    (tl, tr, br, bl) = rect
    widthA = np.linalg.norm(br - bl)
    widthB = np.linalg.norm(tr - tl)
    maxWidth = max(int(widthA), int(widthB))

    heightA = np.linalg.norm(tr - br)
    heightB = np.linalg.norm(tl - bl)
    maxHeight = max(int(heightA), int(heightB))

    # Новое выровненное изображение
    dst = np.array([
        [0, 0],
        [maxWidth - 1, 0],
        [maxWidth - 1, maxHeight - 1],
        [0, maxHeight - 1]], dtype="float32")

    # Преобразование перспективы
    M = cv2.getPerspectiveTransform(rect, dst)
    aligned = cv2.warpPerspective(image, M, (maxWidth, maxHeight))

    return aligned

# Пути к папкам
images_folder = r'F:\grozny\beeline\train_borders\images'
labels_folder = r'F:\grozny\beeline\train_borders\labels'
aligned_folder = r'F:\grozny\beeline\train_borders\align'
# Создание папки для выровненных изображений, если её нет
os.makedirs(aligned_folder, exist_ok=True)

# Обработка всех изображений в папке
for image_filename in os.listdir(images_folder):
    if image_filename.endswith(('.jpg', '.png', '.jpeg')):
        # Формирование путей к изображениям и текстовым файлам
        image_path = os.path.join(images_folder, image_filename)
        label_path = os.path.join(labels_folder, os.path.splitext(image_filename)[0] + '.txt')

        # Загрузка изображения и угловых точек
        image = cv2.imread(image_path)
        corners = load_corners_from_file(label_path)

        # Выравнивание изображения
        aligned_image = align_image(image, corners)

        # Сохранение выровненного изображения
        aligned_image_path = os.path.join(aligned_folder, image_filename)
        cv2.imwrite(aligned_image_path, aligned_image)

print("Все изображения обработаны и сохранены в папке 'align'.")

# %% [markdown]
# # Код извлечения номера региона для обучения сети

# %%
import os
from PIL import Image

# Папки с исходными изображениями и для сохранения
source_folder = r"F:\grozny\beeline\train_borders\align"
destination_folder = r"F:\grozny\beeline\find_region_type"

# Проверка наличия папки назначения, если её нет - создаём
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Нормализованные координаты извлекаемой области (значения от 0 до 1)
# Пример: извлечение центральной части изображения
relative_coordinates = (0.71, 0.05, 0.96, 0.7)

# Проход по всем файлам в исходной папке
for filename in os.listdir(source_folder):
    if filename.endswith(('.jpg', '.jpeg', '.png')):
        # Путь к текущему изображению
        img_path = os.path.join(source_folder, filename)
        
        # Открываем изображение
        img = Image.open(img_path)
        width, height = img.size
        
        # Рассчитываем абсолютные координаты на основе нормализованных
        left = int(relative_coordinates[0] * width)
        top = int(relative_coordinates[1] * height)
        right = int(relative_coordinates[2] * width)
        bottom = int(relative_coordinates[3] * height)
        
        # Обрезаем изображение
        cropped_img = img.crop((left, top, right, bottom))
        
        # Сохраняем обрезанное изображение в папку назначения
        cropped_img.save(os.path.join(destination_folder, filename))

print("Готово!")
# Out:
# Готово!

# %% [markdown]
# # Код разметки извлеченных фрагментов номера региона

# %%
import os
import cv2

# Папка с изображениями для классификации
source_folder = r"F:\grozny\beeline\find_region_type"

# Папка для сохранения классифицированных изображений
destination_folder = r"F:\grozny\beeline\classification_region_type"
class_2_folder = os.path.join(destination_folder, '2')
class_3_folder = os.path.join(destination_folder, '3')

# Создание папок для каждого класса, если они не существуют
os.makedirs(class_2_folder, exist_ok=True)
os.makedirs(class_3_folder, exist_ok=True)

# Размер для масштабирования изображений
resize_dim = (120, 60)

# Получение списка всех файлов в исходной папке
files = [f for f in os.listdir(source_folder) if f.endswith(('.jpg', '.jpeg', '.png'))][330:455]

for filename in files:
    img_path = os.path.join(source_folder, filename)
    img = cv2.imread(img_path)
    
    if img is None:
        print(f"Не удалось открыть изображение {img_path}")
        continue

    # Масштабирование изображения
    resized_img = cv2.resize(img, resize_dim)

    # Показ изображения
    cv2.imshow('Image', resized_img)

    key = cv2.waitKey(0)  # Ожидание нажатия клавиши

    # Копирование изображения в соответствующую папку в зависимости от нажатой клавиши
    if key == ord('f'):
        destination_path = os.path.join(class_2_folder, filename)
        cv2.imwrite(destination_path, resized_img)
        print(f"{filename} сохранено в класс 2")
    elif key == ord('j'):
        destination_path = os.path.join(class_3_folder, filename)
        cv2.imwrite(destination_path, resized_img)
        print(f"{filename} сохранено в класс 3")
    else:
        print(f"{filename} не классифицировано, пропускается")

    cv2.destroyAllWindows()  # Закрыть окно изображения

print("Классификация завершена!")
# Out:
# 546fe58c4726bf96.jpg сохранено в класс 3
# 54b37d1dcaa9904d.jpg сохранено в класс 2
# 54e17facb117450a.jpg сохранено в класс 3
# 54fbca9b449b6a98.jpg сохранено в класс 3
# 5501279f386334ea.jpg сохранено в класс 3
# 551ca2259c57a8d4.jpg сохранено в класс 3
# 5568a6b77639cfea.jpg сохранено в класс 3
# 55a834e4114cda85.jpg сохранено в класс 3
# 55c567b373af4755.jpg сохранено в класс 2
# 55d491d432298b2f.jpg сохранено в класс 2
# 563ec928a2c398a1.jpg сохранено в класс 3
# 56fb003ffded4de3.jpg сохранено в класс 2
# 570d65df46a8af32.jpg сохранено в класс 2
# 5742e66a9afb6b05.jpg сохранено в класс 3
# 57854495d0d25582.jpg сохранено в класс 3
# 5799f56e101a3ec4.jpg сохранено в класс 3
# 57aa85070c8e6a81.jpg сохранено в класс 3
# 57dca93ee0898e5a.jpg сохранено в класс 2
# 58b2228cb7e66614.jpg сохранено в класс 3
# 58e5380fe3e930f1.jpg сохранено в класс 2
# 59bc707325fd5f4a.jpg сохранено в класс 3
# 59c6a0c1c1cc4e3d.jpg сохранено в класс 3
# 59f0f47ae3dab3d3.jpg сохранено в класс 3
# 5a243080d185fe8e.jpg сохранено в класс 3
# 5a350babe99d3b88.jpg сохранено в класс 2
# 5aefa6d4f10aabcb.jpg сохранено в класс 3
# 5b1b456ca02cccf9.jpg сохранено в класс 2
# 5b4b274ecd3beaef.jpg сохранено в класс 3
# 5b5968bc662a131c.jpg сохранено в класс 3
# 5b83ec7ec21f1fab.jpg сохранено в класс 2
# 5be2c5e43775fab1.jpg сохранено в класс 2
# 5c3348a856cf37dd.jpg сохранено в класс 3
# 5c3fa12ce8ef2c2f.jpg сохранено в класс 3
# 5cb9a8c16bc3c670.jpg сохранено в класс 2
# 5cece0d29ee98a52.jpg сохранено в класс 2
# 5cf4d84ace18f1fc.jpg сохранено в класс 2
# 5d2202a43f13c593.jpg сохранено в класс 3
# 5d801600e7a17da9.jpg сохранено в класс 2
# 5d868f1ac7e0ff0c.jpg сохранено в класс 3
# 5dae91fb2c74f3c7.jpg сохранено в класс 3
# 5db54abca1c5daef.jpg сохранено в класс 3
# 5dfc68d343d5fede.jpg сохранено в класс 2
# 5e7ff3a172afee91.jpg сохранено в класс 2
# 5e8299ad90f504c5.jpg сохранено в класс 3
# 5e98e4cb6257f0c7.jpg сохранено в класс 2
# 5ef8fa20964eed06.jpg сохранено в класс 2
# 5fb3e8122c26d391.jpg сохранено в класс 3
# 6018af48faae98e9.jpg сохранено в класс 3
# 6061f532b0da0a81.jpg сохранено в класс 2
# 60a942521bfe1695.jpg сохранено в класс 2
# 60c242c51026d604.jpg сохранено в класс 2
# 61236535e02327a8.jpg сохранено в класс 3
# 613a740b274d63c7.jpg сохранено в класс 3
# 61657d8402532232.jpg сохранено в класс 3
# 616e2995173c1565.jpg сохранено в класс 2
# 61a9253da8bf552f.jpg сохранено в класс 2
# 61d5a7a1f3550fa6.jpg сохранено в класс 3
# 621186dd2f6aec78.jpg сохранено в класс 3
# 62b30e9235715a03.jpg сохранено в класс 3
# 62b98aafec944659.jpg сохранено в класс 2
# 630b64147d66a3df.jpg сохранено в класс 3
# 634c6f974e4e17d9.jpg сохранено в класс 3
# 64393c486444d812.jpg сохранено в класс 2
# 6440d71d9378821b.jpg сохранено в класс 3
# 64474d4aec720d64.jpg сохранено в класс 3
# 646991d31b99e624.jpg сохранено в класс 3
# 64c7ad2cf304dafe.jpg сохранено в класс 2
# 64cc1d3a1d9f6c49.jpg сохранено в класс 3
# 64d0fbcf79e04fa8.jpg сохранено в класс 3
# 658dd7391aa7482a.jpg сохранено в класс 3
# 6594106ca1b49c18.jpg сохранено в класс 2
# 65bb26772510b3e2.jpg сохранено в класс 2
# 65c10a33cd010db3.jpg сохранено в класс 3
# 6604e3bd8a59b387.jpg сохранено в класс 2
# 66a72518ec8bf6e2.jpg сохранено в класс 3
# 66a906fd25bb9f2d.jpg сохранено в класс 2
# 66be4af2964ecd77.jpg сохранено в класс 2
# 66c5e0b890d723c5.jpg сохранено в класс 2
# 66f1b18d61c3a58f.jpg не классифицировано, пропускается
# 670e0ccc5d3c2ea0.jpg сохранено в класс 2
# 678766229b7e4996.jpg сохранено в класс 2
# 67b43fe530222c7b.jpg сохранено в класс 3
# 67c1ad1a0eb71912.jpg сохранено в класс 3
# 67f195cb22ade394.jpg сохранено в класс 3
# 681cab7235b03dae.jpg сохранено в класс 3
# 685de46908062087.jpg сохранено в класс 2
# 68b4b190c0b1a959.jpg сохранено в класс 3
# 68bf98c8dc98da61.jpg сохранено в класс 2
# 68fc99728e71daf8.jpg сохранено в класс 2
# 693cef03e3157f09.jpg сохранено в класс 3
# 694a2bb1cd827439.jpg сохранено в класс 3
# 69642a38359e5fc5.jpg сохранено в класс 3
# 69663090932e145d.jpg сохранено в класс 3
# 69682bb4f00c0097.jpg сохранено в класс 3
# 699f7684c9a97134.jpg сохранено в класс 3
# 69aea47a3eec5f76.jpg сохранено в класс 2
# 6a383088f02247fe.jpg сохранено в класс 2
# 6a5f3c8eed51b714.jpg сохранено в класс 3
# 6a8a1a4fc2b48fdd.jpg сохранено в класс 3
# 6a94a1745c7a1586.jpg сохранено в класс 2
# 6aa642c15f6276a4.jpg сохранено в класс 3
# 6ab5f1cd6c43defc.jpg сохранено в класс 2
# 6b3ba90b7964f81a.jpg сохранено в класс 2
# 6b8db0612ecf128b.jpg сохранено в класс 3
# 6be42e5f4705e24b.jpg сохранено в класс 3
# 6c3b9b57ffe0ac32.jpg сохранено в класс 3
# 6c698226a097bd2b.jpg сохранено в класс 2
# 6d0afa1867eb3b01.jpg сохранено в класс 3
# 6d90605061843acc.jpg сохранено в класс 3
# 6de8e64ac0d4ab1e.jpg сохранено в класс 2
# 6dfa366d7bb732fc.jpg сохранено в класс 2
# 6dfbb2248d7be673.jpg сохранено в класс 2
# 6e556002a88da3dc.jpg сохранено в класс 3
# 6e8d1bf80c9fb292.jpg сохранено в класс 3
# 6ecae089fb21d2f5.jpg сохранено в класс 3
# 6f36e8add9c51a2d.jpg сохранено в класс 2
# 6f3f69f30738c67d.jpg сохранено в класс 3
# 6f5f268543b148d5.jpg сохранено в класс 2
# 7016b2ac9ce3c278.jpg сохранено в класс 3
# 701d4e7c580d6e60.jpg сохранено в класс 2
# 70865f8613c9d4f8.jpg сохранено в класс 3
# 70881a5e20fa2c55.jpg сохранено в класс 3
# 70f5bbd014607529.jpg сохранено в класс 3
# 71137ac28ca1089e.jpg сохранено в класс 2
# 712a65bb4c0f3a3c.jpg сохранено в класс 2
# Классификация завершена!

# %% [markdown]
# # Код разметки символов по положению в трафарете

# %% [markdown]
# ## 3 класса:
# 0 - трафарет нужно сдвинуть влево
# 1 - символ в центре трафарета, ничего не меняем
# 2 - трафарет нужно сдвинуть вправо

# %%
import os
import cv2

# Папка с изображениями для классификации
source_folder = r"F:\grozny\beeline\train_borders\fragments"

# Папка для сохранения классифицированных изображений
destination_folder = r"F:\grozny\beeline\train_borders\recog"
class_0_folder = os.path.join(destination_folder, '0')
class_1_folder = os.path.join(destination_folder, '1')
class_2_folder = os.path.join(destination_folder, '2')

# Создание папок для каждого класса, если они не существуют
os.makedirs(class_0_folder, exist_ok=True)
os.makedirs(class_1_folder, exist_ok=True)
os.makedirs(class_2_folder, exist_ok=True)

# Размер для масштабирования изображений
resize_dim = (64, 64)

# Получение списка всех файлов в исходной папке
files = [f for f in os.listdir(source_folder) if f.endswith(('.jpg', '.jpeg', '.png'))]

for filename in files:
    img_path = os.path.join(source_folder, filename)
    img = cv2.imread(img_path)
    
    if img is None:
        print(f"Не удалось открыть изображение {img_path}")
        continue

    # Масштабирование изображения
    resized_img = cv2.resize(img, resize_dim)

    # Показ изображения
    cv2.imshow('Image', resized_img)

    key = cv2.waitKey(0)  # Ожидание нажатия клавиши

    # Копирование изображения в соответствующую папку в зависимости от нажатой клавиши
    if key == ord('q'):
        destination_path = os.path.join(class_0_folder, filename)
        cv2.imwrite(destination_path, resized_img)
        print(f"{filename} сохранено в класс 0")
    elif key == ord('w'):
        destination_path = os.path.join(class_1_folder, filename)
        cv2.imwrite(destination_path, resized_img)
        print(f"{filename} сохранено в класс 1")
    elif key == ord('e'):
        destination_path = os.path.join(class_2_folder, filename)
        cv2.imwrite(destination_path, resized_img)
        print(f"{filename} сохранено в класс 2")
    else:
        print(f"{filename} не классифицировано, пропускается")

    cv2.destroyAllWindows()  # Закрыть окно изображения

print("Классификация завершена!")
# Out:
# 002d28e4d47606a2_pos1.png сохранено в класс 1
# 002d28e4d47606a2_pos2.png сохранено в класс 1
# 002d28e4d47606a2_pos3.png сохранено в класс 1
# 002d28e4d47606a2_pos4.png сохранено в класс 2
# 002d28e4d47606a2_pos5.png сохранено в класс 2
# 002d28e4d47606a2_pos6.png сохранено в класс 2
# 002d28e4d47606a2_pos7.png не классифицировано, пропускается
# 002d28e4d47606a2_pos8.png сохранено в класс 1
# 002d28e4d47606a2_pos9.png сохранено в класс 1
# 0096f97c017f7545_pos1.png сохранено в класс 1
# 0096f97c017f7545_pos2.png сохранено в класс 0
# 0096f97c017f7545_pos3.png сохранено в класс 0
# 0096f97c017f7545_pos4.png сохранено в класс 0
# 0096f97c017f7545_pos5.png сохранено в класс 0
# 0096f97c017f7545_pos6.png сохранено в класс 0
# 0096f97c017f7545_pos7.png сохранено в класс 1
# 0096f97c017f7545_pos8.png сохранено в класс 1
# 00c980fd3135c4af_pos1.png сохранено в класс 1
# 00c980fd3135c4af_pos2.png сохранено в класс 1
# 00c980fd3135c4af_pos3.png сохранено в класс 2
# 00c980fd3135c4af_pos4.png сохранено в класс 1
# 00c980fd3135c4af_pos5.png сохранено в класс 2
# 00c980fd3135c4af_pos6.png сохранено в класс 2
# 00c980fd3135c4af_pos7.png не классифицировано, пропускается
# 00c980fd3135c4af_pos8.png сохранено в класс 1
# 00c980fd3135c4af_pos9.png сохранено в класс 1
# 01897be6257badd0_pos1.png сохранено в класс 1
# 01897be6257badd0_pos2.png сохранено в класс 1
# 01897be6257badd0_pos3.png сохранено в класс 0
# 01897be6257badd0_pos4.png сохранено в класс 1
# 01897be6257badd0_pos5.png сохранено в класс 1
# 01897be6257badd0_pos6.png сохранено в класс 1
# 01897be6257badd0_pos7.png сохранено в класс 1
# 01897be6257badd0_pos8.png сохранено в класс 1
# 01897be6257badd0_pos9.png сохранено в класс 1
# 0200960b932ac52f_pos1.png сохранено в класс 1
# 0200960b932ac52f_pos2.png сохранено в класс 2
# 0200960b932ac52f_pos3.png сохранено в класс 2
# 0200960b932ac52f_pos4.png сохранено в класс 2
# 0200960b932ac52f_pos5.png сохранено в класс 2
# 0200960b932ac52f_pos6.png сохранено в класс 2
# 0200960b932ac52f_pos7.png не классифицировано, пропускается
# 0200960b932ac52f_pos8.png сохранено в класс 1
# 0200960b932ac52f_pos9.png сохранено в класс 1
# 0203b97d21f95a7c_pos1.png сохранено в класс 1
# 0203b97d21f95a7c_pos2.png сохранено в класс 1
# 0203b97d21f95a7c_pos3.png сохранено в класс 1
# 0203b97d21f95a7c_pos4.png сохранено в класс 1
# 0203b97d21f95a7c_pos5.png сохранено в класс 1
# 0203b97d21f95a7c_pos6.png сохранено в класс 1
# 0203b97d21f95a7c_pos7.png сохранено в класс 2
# 0203b97d21f95a7c_pos8.png сохранено в класс 2
# 0203b97d21f95a7c_pos9.png сохранено в класс 2
# 022e896c07262f6c_pos1.png сохранено в класс 1
# 022e896c07262f6c_pos2.png сохранено в класс 1
# 022e896c07262f6c_pos3.png сохранено в класс 1
# 022e896c07262f6c_pos4.png сохранено в класс 1
# 022e896c07262f6c_pos5.png сохранено в класс 1
# 022e896c07262f6c_pos6.png сохранено в класс 1
# 022e896c07262f6c_pos7.png сохранено в класс 1
# 022e896c07262f6c_pos8.png сохранено в класс 1
# 022e896c07262f6c_pos9.png сохранено в класс 1
# 0234b2e153d1fb14_pos1.png сохранено в класс 1
# 0234b2e153d1fb14_pos2.png сохранено в класс 1
# 0234b2e153d1fb14_pos3.png сохранено в класс 1
# 0234b2e153d1fb14_pos4.png сохранено в класс 1
# 0234b2e153d1fb14_pos5.png сохранено в класс 1
# 0234b2e153d1fb14_pos6.png сохранено в класс 2
# 0234b2e153d1fb14_pos7.png не классифицировано, пропускается
# 0234b2e153d1fb14_pos8.png сохранено в класс 2
# 0234b2e153d1fb14_pos9.png сохранено в класс 2
# 027e1840809d6611_pos1.png сохранено в класс 0
# 027e1840809d6611_pos2.png сохранено в класс 0
# 027e1840809d6611_pos3.png сохранено в класс 0
# 027e1840809d6611_pos4.png сохранено в класс 0
# 027e1840809d6611_pos5.png сохранено в класс 0
# 027e1840809d6611_pos6.png сохранено в класс 0
# 027e1840809d6611_pos7.png сохранено в класс 1
# 027e1840809d6611_pos8.png сохранено в класс 1
# 027e1840809d6611_pos9.png сохранено в класс 1
# 02b326fe0ea901d6_pos1.png сохранено в класс 0
# 02b326fe0ea901d6_pos2.png сохранено в класс 0
# 02b326fe0ea901d6_pos3.png сохранено в класс 0
# 02b326fe0ea901d6_pos4.png сохранено в класс 0
# 02b326fe0ea901d6_pos5.png сохранено в класс 0
# 02b326fe0ea901d6_pos6.png сохранено в класс 0
# 02b326fe0ea901d6_pos7.png сохранено в класс 0
# 02b326fe0ea901d6_pos8.png сохранено в класс 0
# 030e79615dc8d57b_pos1.png сохранено в класс 1
# 030e79615dc8d57b_pos2.png сохранено в класс 1
# 030e79615dc8d57b_pos3.png сохранено в класс 2
# 030e79615dc8d57b_pos4.png сохранено в класс 2
# 030e79615dc8d57b_pos5.png сохранено в класс 2
# 030e79615dc8d57b_pos6.png сохранено в класс 2
# 030e79615dc8d57b_pos7.png не классифицировано, пропускается
# 030e79615dc8d57b_pos8.png сохранено в класс 1
# 030e79615dc8d57b_pos9.png сохранено в класс 1
# 0353c457a0040c51_pos1.png сохранено в класс 1
# 0353c457a0040c51_pos2.png сохранено в класс 1
# 0353c457a0040c51_pos3.png сохранено в класс 1
# 0353c457a0040c51_pos4.png сохранено в класс 1
# 0353c457a0040c51_pos5.png сохранено в класс 1
# 0353c457a0040c51_pos6.png сохранено в класс 1
# 0353c457a0040c51_pos7.png сохранено в класс 2
# 0353c457a0040c51_pos8.png сохранено в класс 2
# 0353c457a0040c51_pos9.png сохранено в класс 1
# 03a3ee817d3aaa2f_pos1.png сохранено в класс 1
# 03a3ee817d3aaa2f_pos2.png сохранено в класс 2
# 03a3ee817d3aaa2f_pos3.png сохранено в класс 1
# 03a3ee817d3aaa2f_pos4.png сохранено в класс 2
# 03a3ee817d3aaa2f_pos5.png сохранено в класс 2
# 03a3ee817d3aaa2f_pos6.png сохранено в класс 2
# 03a3ee817d3aaa2f_pos7.png не классифицировано, пропускается
# 03a3ee817d3aaa2f_pos8.png сохранено в класс 0
# 03a3ee817d3aaa2f_pos9.png сохранено в класс 1
# 03a58663af05bef7_pos1.png сохранено в класс 0
# 03a58663af05bef7_pos2.png сохранено в класс 0
# 03a58663af05bef7_pos3.png сохранено в класс 1
# 03a58663af05bef7_pos4.png сохранено в класс 1
# 03a58663af05bef7_pos5.png сохранено в класс 1
# 03a58663af05bef7_pos6.png сохранено в класс 2
# 03a58663af05bef7_pos7.png сохранено в класс 2
# 03a58663af05bef7_pos8.png сохранено в класс 2
# 03a58663af05bef7_pos9.png сохранено в класс 2
# 03b2a0e103507f2c_pos1.png сохранено в класс 1
# 03b2a0e103507f2c_pos2.png сохранено в класс 1
# 03b2a0e103507f2c_pos3.png сохранено в класс 1
# 03b2a0e103507f2c_pos4.png сохранено в класс 2
# 03b2a0e103507f2c_pos5.png сохранено в класс 2
# 03b2a0e103507f2c_pos6.png сохранено в класс 2
# 03b2a0e103507f2c_pos7.png не классифицировано, пропускается
# 03b2a0e103507f2c_pos8.png сохранено в класс 1
# 03b2a0e103507f2c_pos9.png сохранено в класс 1
# 048024974d39da5b_pos1.png сохранено в класс 1
# 048024974d39da5b_pos2.png сохранено в класс 1
# 048024974d39da5b_pos3.png сохранено в класс 1
# 048024974d39da5b_pos4.png сохранено в класс 1
# 048024974d39da5b_pos5.png сохранено в класс 1
# 048024974d39da5b_pos6.png сохранено в класс 1
# 048024974d39da5b_pos7.png сохранено в класс 1
# 048024974d39da5b_pos8.png сохранено в класс 1
# 048024974d39da5b_pos9.png сохранено в класс 1
# 049df008076b541f_pos1.png сохранено в класс 1
# 049df008076b541f_pos2.png сохранено в класс 2
# 049df008076b541f_pos3.png сохранено в класс 2
# 049df008076b541f_pos4.png сохранено в класс 2
# 049df008076b541f_pos5.png сохранено в класс 2
# 049df008076b541f_pos6.png сохранено в класс 0
# 049df008076b541f_pos7.png не классифицировано, пропускается
# 049df008076b541f_pos8.png сохранено в класс 1
# 049df008076b541f_pos9.png сохранено в класс 1
# 04ba5f4ca0f8296d_pos1.png сохранено в класс 0
# 04ba5f4ca0f8296d_pos2.png сохранено в класс 1
# 04ba5f4ca0f8296d_pos3.png сохранено в класс 1
# 04ba5f4ca0f8296d_pos4.png сохранено в класс 1
# 04ba5f4ca0f8296d_pos5.png сохранено в класс 1
# 04ba5f4ca0f8296d_pos6.png сохранено в класс 2
# 04ba5f4ca0f8296d_pos7.png сохранено в класс 2
# 04ba5f4ca0f8296d_pos8.png сохранено в класс 2
# 04ba5f4ca0f8296d_pos9.png сохранено в класс 2
# 0556dd00e20e7977_pos1.png сохранено в класс 1
# 0556dd00e20e7977_pos2.png сохранено в класс 2
# 0556dd00e20e7977_pos3.png сохранено в класс 2
# 0556dd00e20e7977_pos4.png сохранено в класс 2
# 0556dd00e20e7977_pos5.png сохранено в класс 2
# 0556dd00e20e7977_pos6.png сохранено в класс 0
# 0556dd00e20e7977_pos7.png не классифицировано, пропускается
# 0556dd00e20e7977_pos8.png сохранено в класс 1
# 0556dd00e20e7977_pos9.png сохранено в класс 1
# 0564781d52c0ed11_pos1.png сохранено в класс 1
# 0564781d52c0ed11_pos2.png сохранено в класс 1
# 0564781d52c0ed11_pos3.png сохранено в класс 1
# 0564781d52c0ed11_pos4.png сохранено в класс 2
# 0564781d52c0ed11_pos5.png сохранено в класс 2
# 0564781d52c0ed11_pos6.png сохранено в класс 2
# 0564781d52c0ed11_pos7.png не классифицировано, пропускается
# 0564781d52c0ed11_pos8.png сохранено в класс 0
# 0564781d52c0ed11_pos9.png сохранено в класс 1
# 05afe0f65aff91ee_pos1.png сохранено в класс 1
# 05afe0f65aff91ee_pos2.png сохранено в класс 1
# 05afe0f65aff91ee_pos3.png сохранено в класс 1
# 05afe0f65aff91ee_pos4.png сохранено в класс 1
# 05afe0f65aff91ee_pos5.png сохранено в класс 1
# 05afe0f65aff91ee_pos6.png сохранено в класс 1
# 05afe0f65aff91ee_pos7.png сохранено в класс 1
# 05afe0f65aff91ee_pos8.png сохранено в класс 1
# 05afe0f65aff91ee_pos9.png сохранено в класс 2
# 05be91f5032c0f79_pos1.png сохранено в класс 1
# 05be91f5032c0f79_pos2.png сохранено в класс 1
# 05be91f5032c0f79_pos3.png сохранено в класс 2
# 05be91f5032c0f79_pos4.png сохранено в класс 2
# 05be91f5032c0f79_pos5.png сохранено в класс 2
# 05be91f5032c0f79_pos6.png сохранено в класс 2
# 05be91f5032c0f79_pos7.png не классифицировано, пропускается
# 05be91f5032c0f79_pos8.png сохранено в класс 1
# 05be91f5032c0f79_pos9.png сохранено в класс 1
# 060907044a5815a7_pos1.png сохранено в класс 1
# 060907044a5815a7_pos2.png сохранено в класс 0
# 060907044a5815a7_pos3.png сохранено в класс 0
# 060907044a5815a7_pos4.png сохранено в класс 0
# 060907044a5815a7_pos5.png сохранено в класс 0
# 060907044a5815a7_pos6.png сохранено в класс 0
# 060907044a5815a7_pos7.png сохранено в класс 1
# 060907044a5815a7_pos8.png сохранено в класс 1
# 061afaddcadfa91f_pos1.png сохранено в класс 1
# 061afaddcadfa91f_pos2.png сохранено в класс 1
# 061afaddcadfa91f_pos3.png сохранено в класс 1
# 061afaddcadfa91f_pos4.png сохранено в класс 1
# 061afaddcadfa91f_pos5.png сохранено в класс 1
# 061afaddcadfa91f_pos6.png сохранено в класс 1
# 061afaddcadfa91f_pos7.png сохранено в класс 1
# 061afaddcadfa91f_pos8.png сохранено в класс 1
# 061afaddcadfa91f_pos9.png сохранено в класс 1
# 0624434f74cd41b1_pos1.png сохранено в класс 1
# 0624434f74cd41b1_pos2.png сохранено в класс 2
# 0624434f74cd41b1_pos3.png сохранено в класс 2
# 0624434f74cd41b1_pos4.png сохранено в класс 2
# 0624434f74cd41b1_pos5.png сохранено в класс 2
# 0624434f74cd41b1_pos6.png сохранено в класс 0
# 0624434f74cd41b1_pos7.png не классифицировано, пропускается
# 0624434f74cd41b1_pos8.png сохранено в класс 1
# 0624434f74cd41b1_pos9.png сохранено в класс 1
# 067f4d516c4df3d7_pos1.png сохранено в класс 2
# 067f4d516c4df3d7_pos2.png сохранено в класс 0
# 067f4d516c4df3d7_pos3.png сохранено в класс 2
# 067f4d516c4df3d7_pos4.png сохранено в класс 0
# 067f4d516c4df3d7_pos5.png сохранено в класс 2
# 067f4d516c4df3d7_pos6.png сохранено в класс 0
# 067f4d516c4df3d7_pos7.png сохранено в класс 1
# 067f4d516c4df3d7_pos8.png сохранено в класс 1
# 0696f8013f9275c3_pos1.png сохранено в класс 1
# 0696f8013f9275c3_pos2.png сохранено в класс 1
# 0696f8013f9275c3_pos3.png сохранено в класс 1
# 0696f8013f9275c3_pos4.png сохранено в класс 1
# 0696f8013f9275c3_pos5.png сохранено в класс 2
# 0696f8013f9275c3_pos6.png сохранено в класс 2
# 0696f8013f9275c3_pos7.png не классифицировано, пропускается
# 0696f8013f9275c3_pos8.png сохранено в класс 1
# 0696f8013f9275c3_pos9.png сохранено в класс 1
# 0754b211a1e54227_pos1.png сохранено в класс 1
# 0754b211a1e54227_pos2.png сохранено в класс 1
# 0754b211a1e54227_pos3.png сохранено в класс 1
# 0754b211a1e54227_pos4.png сохранено в класс 1
# 0754b211a1e54227_pos5.png сохранено в класс 1
# 0754b211a1e54227_pos6.png сохранено в класс 1
# 0754b211a1e54227_pos7.png сохранено в класс 1
# 0754b211a1e54227_pos8.png сохранено в класс 1
# 0754b211a1e54227_pos9.png сохранено в класс 1
# 07cf1869ead32f07_pos1.png сохранено в класс 1
# 07cf1869ead32f07_pos2.png сохранено в класс 1
# 07cf1869ead32f07_pos3.png сохранено в класс 0
# 07cf1869ead32f07_pos4.png сохранено в класс 0
# 07cf1869ead32f07_pos5.png сохранено в класс 0
# 07cf1869ead32f07_pos6.png сохранено в класс 0
# 07cf1869ead32f07_pos7.png сохранено в класс 0
# 07cf1869ead32f07_pos8.png сохранено в класс 0
# 083e78e678ccfec9_pos1.png сохранено в класс 0
# 083e78e678ccfec9_pos2.png сохранено в класс 0
# 083e78e678ccfec9_pos3.png сохранено в класс 0
# 083e78e678ccfec9_pos4.png сохранено в класс 0
# 083e78e678ccfec9_pos5.png сохранено в класс 0
# 083e78e678ccfec9_pos6.png сохранено в класс 1
# 083e78e678ccfec9_pos7.png не классифицировано, пропускается
# 083e78e678ccfec9_pos8.png не классифицировано, пропускается
# 08410bc6692868ba_pos1.png сохранено в класс 1
# 08410bc6692868ba_pos2.png сохранено в класс 2
# 08410bc6692868ba_pos3.png сохранено в класс 2
# 08410bc6692868ba_pos4.png сохранено в класс 2
# 08410bc6692868ba_pos5.png сохранено в класс 2
# 08410bc6692868ba_pos6.png сохранено в класс 0
# 08410bc6692868ba_pos7.png сохранено в класс 2
# 08410bc6692868ba_pos8.png сохранено в класс 1
# 08410bc6692868ba_pos9.png сохранено в класс 1
# 088ea5bdf539bc08_pos1.png сохранено в класс 0
# 088ea5bdf539bc08_pos2.png сохранено в класс 0
# 088ea5bdf539bc08_pos3.png сохранено в класс 0
# 088ea5bdf539bc08_pos4.png сохранено в класс 0
# 088ea5bdf539bc08_pos5.png сохранено в класс 0
# 088ea5bdf539bc08_pos6.png сохранено в класс 0
# 088ea5bdf539bc08_pos7.png сохранено в класс 2
# 088ea5bdf539bc08_pos8.png сохранено в класс 2
# 09693e5256924321_pos1.png сохранено в класс 1
# 09693e5256924321_pos2.png сохранено в класс 1
# 09693e5256924321_pos3.png сохранено в класс 1
# 09693e5256924321_pos4.png сохранено в класс 1
# 09693e5256924321_pos5.png сохранено в класс 0
# 09693e5256924321_pos6.png сохранено в класс 0
# 09693e5256924321_pos7.png сохранено в класс 0
# 09693e5256924321_pos8.png сохранено в класс 2
# 0998e05b77629df5_pos1.png сохранено в класс 1
# 0998e05b77629df5_pos2.png сохранено в класс 1
# 0998e05b77629df5_pos3.png сохранено в класс 1
# 0998e05b77629df5_pos4.png сохранено в класс 1
# 0998e05b77629df5_pos5.png сохранено в класс 1
# 0998e05b77629df5_pos6.png сохранено в класс 1
# 0998e05b77629df5_pos7.png сохранено в класс 1
# 0998e05b77629df5_pos8.png сохранено в класс 1
# 09a615a86b534289_pos1.png сохранено в класс 0
# 09a615a86b534289_pos2.png сохранено в класс 0
# 09a615a86b534289_pos3.png сохранено в класс 0
# 09a615a86b534289_pos4.png сохранено в класс 0
# 09a615a86b534289_pos5.png сохранено в класс 2
# 09a615a86b534289_pos6.png сохранено в класс 0
# 09a615a86b534289_pos7.png сохранено в класс 2
# 09a615a86b534289_pos8.png сохранено в класс 2
# 09ad0e9c72211b7f_pos1.png сохранено в класс 0
# 09ad0e9c72211b7f_pos2.png сохранено в класс 1
# 09ad0e9c72211b7f_pos3.png сохранено в класс 1
# 09ad0e9c72211b7f_pos4.png сохранено в класс 1
# 09ad0e9c72211b7f_pos5.png сохранено в класс 1
# 09ad0e9c72211b7f_pos6.png сохранено в класс 1
# 09ad0e9c72211b7f_pos7.png сохранено в класс 2
# 09ad0e9c72211b7f_pos8.png сохранено в класс 2
# 09ad0e9c72211b7f_pos9.png сохранено в класс 2
# 09b2962f19b20498_pos1.png сохранено в класс 1
# 09b2962f19b20498_pos2.png сохранено в класс 1
# 09b2962f19b20498_pos3.png сохранено в класс 1
# 09b2962f19b20498_pos4.png сохранено в класс 1
# 09b2962f19b20498_pos5.png сохранено в класс 1
# 09b2962f19b20498_pos6.png сохранено в класс 1
# 09b2962f19b20498_pos7.png сохранено в класс 2
# 09b2962f19b20498_pos8.png сохранено в класс 1
# 09b2962f19b20498_pos9.png сохранено в класс 2
# 09b397ad8467be6b_pos1.png сохранено в класс 1
# 09b397ad8467be6b_pos2.png сохранено в класс 1
# 09b397ad8467be6b_pos3.png сохранено в класс 1
# 09b397ad8467be6b_pos4.png сохранено в класс 1
# 09b397ad8467be6b_pos5.png сохранено в класс 1
# 09b397ad8467be6b_pos6.png сохранено в класс 1
# 09b397ad8467be6b_pos7.png сохранено в класс 1
# 09b397ad8467be6b_pos8.png сохранено в класс 1
# 09b397ad8467be6b_pos9.png сохранено в класс 1
# 0a6aa844e3834971_pos1.png сохранено в класс 0
# 0a6aa844e3834971_pos2.png сохранено в класс 0
# 0a6aa844e3834971_pos3.png сохранено в класс 2
# 0a6aa844e3834971_pos4.png сохранено в класс 0
# 0a6aa844e3834971_pos5.png сохранено в класс 2
# 0a6aa844e3834971_pos6.png не классифицировано, пропускается
# 0a6aa844e3834971_pos7.png сохранено в класс 2
# 0a6aa844e3834971_pos8.png сохранено в класс 2
# 0a8438252d687e6e_pos1.png сохранено в класс 0
# 0a8438252d687e6e_pos2.png сохранено в класс 0
# 0a8438252d687e6e_pos3.png сохранено в класс 0
# 0a8438252d687e6e_pos4.png сохранено в класс 0
# 0a8438252d687e6e_pos5.png сохранено в класс 0
# 0a8438252d687e6e_pos6.png не классифицировано, пропускается
# 0a8438252d687e6e_pos7.png не классифицировано, пропускается
# 0a8438252d687e6e_pos8.png не классифицировано, пропускается
# 0ac22544b27be4ef_pos1.png не классифицировано, пропускается
# 0ac22544b27be4ef_pos2.png сохранено в класс 1
# 0ac22544b27be4ef_pos3.png сохранено в класс 1
# 0ac22544b27be4ef_pos4.png сохранено в класс 1
# 0ac22544b27be4ef_pos5.png сохранено в класс 1
# 0ac22544b27be4ef_pos6.png сохранено в класс 1
# 0ac22544b27be4ef_pos7.png сохранено в класс 1
# 0ac22544b27be4ef_pos8.png сохранено в класс 1
# 0ac22544b27be4ef_pos9.png сохранено в класс 1
# 0b288ece14de5bb5_pos1.png сохранено в класс 1
# 0b288ece14de5bb5_pos2.png сохранено в класс 0
# 0b288ece14de5bb5_pos3.png сохранено в класс 0
# 0b288ece14de5bb5_pos4.png сохранено в класс 0
# 0b288ece14de5bb5_pos5.png сохранено в класс 0
# 0b288ece14de5bb5_pos6.png сохранено в класс 0
# 0b288ece14de5bb5_pos7.png сохранено в класс 0
# 0b288ece14de5bb5_pos8.png сохранено в класс 1
# 0b59a6532708ac55_pos1.png сохранено в класс 0
# 0b59a6532708ac55_pos2.png сохранено в класс 1
# 0b59a6532708ac55_pos3.png сохранено в класс 1
# 0b59a6532708ac55_pos4.png сохранено в класс 1
# 0b59a6532708ac55_pos5.png сохранено в класс 1
# 0b59a6532708ac55_pos6.png сохранено в класс 1
# 0b59a6532708ac55_pos7.png сохранено в класс 1
# 0b59a6532708ac55_pos8.png сохранено в класс 1
# 0b5e5490607902fe_pos1.png сохранено в класс 1
# 0b5e5490607902fe_pos2.png сохранено в класс 0
# 0b5e5490607902fe_pos3.png сохранено в класс 0
# 0b5e5490607902fe_pos4.png сохранено в класс 0
# 0b5e5490607902fe_pos5.png сохранено в класс 0
# 0b5e5490607902fe_pos6.png сохранено в класс 1
# 0b5e5490607902fe_pos7.png сохранено в класс 0
# 0b5e5490607902fe_pos8.png сохранено в класс 1
# 0b5e5490607902fe_pos9.png сохранено в класс 1
# 0b90c1c74d46abf7_pos1.png сохранено в класс 1
# 0b90c1c74d46abf7_pos2.png сохранено в класс 1
# 0b90c1c74d46abf7_pos3.png сохранено в класс 1
# 0b90c1c74d46abf7_pos4.png сохранено в класс 1
# 0b90c1c74d46abf7_pos5.png сохранено в класс 1
# 0b90c1c74d46abf7_pos6.png сохранено в класс 2
# 0b90c1c74d46abf7_pos7.png сохранено в класс 2
# 0b90c1c74d46abf7_pos8.png сохранено в класс 2
# 0b90c1c74d46abf7_pos9.png сохранено в класс 2
# 0ba8604c47f8db05_pos1.png сохранено в класс 1
# 0ba8604c47f8db05_pos2.png сохранено в класс 0
# 0ba8604c47f8db05_pos3.png сохранено в класс 0
# 0ba8604c47f8db05_pos4.png сохранено в класс 0
# 0ba8604c47f8db05_pos5.png сохранено в класс 0
# 0ba8604c47f8db05_pos6.png сохранено в класс 0
# 0ba8604c47f8db05_pos7.png сохранено в класс 1
# 0ba8604c47f8db05_pos8.png сохранено в класс 1
# 0ba8604c47f8db05_pos9.png сохранено в класс 1
# 0d4d5d201326a391_pos1.png сохранено в класс 1
# 0d4d5d201326a391_pos2.png сохранено в класс 2
# 0d4d5d201326a391_pos3.png сохранено в класс 2
# 0d4d5d201326a391_pos4.png сохранено в класс 2
# 0d4d5d201326a391_pos5.png сохранено в класс 2
# 0d4d5d201326a391_pos6.png сохранено в класс 2
# 0d4d5d201326a391_pos7.png не классифицировано, пропускается
# 0d4d5d201326a391_pos8.png сохранено в класс 1
# 0d4d5d201326a391_pos9.png сохранено в класс 1
# 0d6975cbf354c86a_pos1.png сохранено в класс 1
# 0d6975cbf354c86a_pos2.png сохранено в класс 1
# 0d6975cbf354c86a_pos3.png сохранено в класс 1
# 0d6975cbf354c86a_pos4.png сохранено в класс 1
# 0d6975cbf354c86a_pos5.png сохранено в класс 1
# 0d6975cbf354c86a_pos6.png сохранено в класс 1
# 0d6975cbf354c86a_pos7.png сохранено в класс 1
# 0d6975cbf354c86a_pos8.png сохранено в класс 1
# 0d6975cbf354c86a_pos9.png сохранено в класс 1
# 0d8b986f6861f08e_pos1.png сохранено в класс 1
# 0d8b986f6861f08e_pos2.png сохранено в класс 0
# 0d8b986f6861f08e_pos3.png сохранено в класс 0
# 0d8b986f6861f08e_pos4.png сохранено в класс 0
# 0d8b986f6861f08e_pos5.png сохранено в класс 0
# 0d8b986f6861f08e_pos6.png сохранено в класс 0
# 0d8b986f6861f08e_pos7.png сохранено в класс 2
# 0d8b986f6861f08e_pos8.png сохранено в класс 2
# 0d915cba254e1565_pos1.png сохранено в класс 0
# 0d915cba254e1565_pos2.png сохранено в класс 0
# 0d915cba254e1565_pos3.png сохранено в класс 0
# 0d915cba254e1565_pos4.png сохранено в класс 0
# 0d915cba254e1565_pos5.png сохранено в класс 2
# 0d915cba254e1565_pos6.png сохранено в класс 0
# 0d915cba254e1565_pos7.png сохранено в класс 2
# 0d915cba254e1565_pos8.png сохранено в класс 2
# 0db7d9dec6882ec7_pos1.png сохранено в класс 1
# 0db7d9dec6882ec7_pos2.png сохранено в класс 1
# 0db7d9dec6882ec7_pos3.png сохранено в класс 1
# 0db7d9dec6882ec7_pos4.png сохранено в класс 1
# 0db7d9dec6882ec7_pos5.png сохранено в класс 1
# 0db7d9dec6882ec7_pos6.png сохранено в класс 1
# 0db7d9dec6882ec7_pos7.png сохранено в класс 1
# 0db7d9dec6882ec7_pos8.png сохранено в класс 1
# 0db7d9dec6882ec7_pos9.png сохранено в класс 1
# 0e11aa3d925e8181_pos1.png сохранено в класс 1
# 0e11aa3d925e8181_pos2.png сохранено в класс 1
# 0e11aa3d925e8181_pos3.png сохранено в класс 1
# 0e11aa3d925e8181_pos4.png сохранено в класс 1
# 0e11aa3d925e8181_pos5.png сохранено в класс 1
# 0e11aa3d925e8181_pos6.png сохранено в класс 1
# 0e11aa3d925e8181_pos7.png сохранено в класс 1
# 0e11aa3d925e8181_pos8.png сохранено в класс 1
# 0e11aa3d925e8181_pos9.png сохранено в класс 1
# 0e9c56305f960d26_pos1.png сохранено в класс 0
# 0e9c56305f960d26_pos2.png сохранено в класс 1
# 0e9c56305f960d26_pos3.png сохранено в класс 1
# 0e9c56305f960d26_pos4.png сохранено в класс 1
# 0e9c56305f960d26_pos5.png сохранено в класс 1
# 0e9c56305f960d26_pos6.png сохранено в класс 1
# 0e9c56305f960d26_pos7.png сохранено в класс 1
# 0e9c56305f960d26_pos8.png сохранено в класс 1
# 0e9c56305f960d26_pos9.png сохранено в класс 1
# 0ebf46d7047bf357_pos1.png сохранено в класс 1
# 0ebf46d7047bf357_pos2.png сохранено в класс 1
# 0ebf46d7047bf357_pos3.png сохранено в класс 1
# 0ebf46d7047bf357_pos4.png сохранено в класс 1
# 0ebf46d7047bf357_pos5.png сохранено в класс 1
# 0ebf46d7047bf357_pos6.png сохранено в класс 0
# 0ebf46d7047bf357_pos7.png сохранено в класс 1
# 0ebf46d7047bf357_pos8.png сохранено в класс 1
# 0ed0a1268f6afb9b_pos1.png сохранено в класс 0
# 0ed0a1268f6afb9b_pos2.png сохранено в класс 0
# 0ed0a1268f6afb9b_pos3.png сохранено в класс 0
# 0ed0a1268f6afb9b_pos4.png сохранено в класс 0
# 0ed0a1268f6afb9b_pos5.png сохранено в класс 1
# 0ed0a1268f6afb9b_pos6.png сохранено в класс 1
# 0ed0a1268f6afb9b_pos7.png сохранено в класс 1
# 0ed0a1268f6afb9b_pos8.png сохранено в класс 1
# 0ed0a1268f6afb9b_pos9.png сохранено в класс 1
# 0f06bd96d353e3ff_pos1.png сохранено в класс 1
# 0f06bd96d353e3ff_pos2.png сохранено в класс 1
# 0f06bd96d353e3ff_pos3.png сохранено в класс 1
# 0f06bd96d353e3ff_pos4.png сохранено в класс 2
# 0f06bd96d353e3ff_pos5.png сохранено в класс 1
# 0f06bd96d353e3ff_pos6.png сохранено в класс 2
# 0f06bd96d353e3ff_pos7.png не классифицировано, пропускается
# 0f06bd96d353e3ff_pos8.png сохранено в класс 1
# 0f06bd96d353e3ff_pos9.png сохранено в класс 1
# 0f2600d1bb0f462a_pos1.png сохранено в класс 1
# 0f2600d1bb0f462a_pos2.png сохранено в класс 1
# 0f2600d1bb0f462a_pos3.png сохранено в класс 1
# 0f2600d1bb0f462a_pos4.png сохранено в класс 1
# 0f2600d1bb0f462a_pos5.png сохранено в класс 1
# 0f2600d1bb0f462a_pos6.png сохранено в класс 1
# 0f2600d1bb0f462a_pos7.png сохранено в класс 1
# 0f2600d1bb0f462a_pos8.png сохранено в класс 1
# 0f2600d1bb0f462a_pos9.png сохранено в класс 1
# 0f29ae00b24d1499_pos1.png сохранено в класс 0
# 0f29ae00b24d1499_pos2.png сохранено в класс 0
# 0f29ae00b24d1499_pos3.png сохранено в класс 0
# 0f29ae00b24d1499_pos4.png сохранено в класс 0
# 0f29ae00b24d1499_pos5.png сохранено в класс 0
# 0f29ae00b24d1499_pos6.png сохранено в класс 0
# 0f29ae00b24d1499_pos7.png сохранено в класс 2
# 0f29ae00b24d1499_pos8.png сохранено в класс 2
# 0f3e9d1f3818f7f0_pos1.png сохранено в класс 1
# 0f3e9d1f3818f7f0_pos2.png сохранено в класс 0
# 0f3e9d1f3818f7f0_pos3.png сохранено в класс 0
# 0f3e9d1f3818f7f0_pos4.png сохранено в класс 0
# 0f3e9d1f3818f7f0_pos5.png сохранено в класс 0
# 0f3e9d1f3818f7f0_pos6.png сохранено в класс 0
# 0f3e9d1f3818f7f0_pos7.png сохранено в класс 0
# 0f3e9d1f3818f7f0_pos8.png сохранено в класс 1
# 0f529e0ef618fbb2_pos1.png сохранено в класс 0
# 0f529e0ef618fbb2_pos2.png сохранено в класс 1
# 0f529e0ef618fbb2_pos3.png сохранено в класс 1
# 0f529e0ef618fbb2_pos4.png сохранено в класс 1
# 0f529e0ef618fbb2_pos5.png сохранено в класс 1
# 0f529e0ef618fbb2_pos6.png сохранено в класс 2
# 0f529e0ef618fbb2_pos7.png сохранено в класс 2
# 0f529e0ef618fbb2_pos8.png сохранено в класс 2
# 0f529e0ef618fbb2_pos9.png сохранено в класс 2
# 0f977c44cd8e3f7a_pos1.png сохранено в класс 0
# 0f977c44cd8e3f7a_pos2.png сохранено в класс 0
# 0f977c44cd8e3f7a_pos3.png сохранено в класс 0
# 0f977c44cd8e3f7a_pos4.png сохранено в класс 0
# 0f977c44cd8e3f7a_pos5.png сохранено в класс 0
# 0f977c44cd8e3f7a_pos6.png сохранено в класс 1
# 0f977c44cd8e3f7a_pos7.png сохранено в класс 1
# 0f977c44cd8e3f7a_pos8.png сохранено в класс 1
# 0f977c44cd8e3f7a_pos9.png сохранено в класс 2
# 10065108a94db3f1_pos1.png сохранено в класс 1
# 10065108a94db3f1_pos2.png сохранено в класс 1
# 10065108a94db3f1_pos3.png сохранено в класс 1
# 10065108a94db3f1_pos4.png сохранено в класс 1
# 10065108a94db3f1_pos5.png сохранено в класс 2
# 10065108a94db3f1_pos6.png сохранено в класс 2
# 10065108a94db3f1_pos7.png сохранено в класс 2
# 10065108a94db3f1_pos8.png сохранено в класс 2
# 100a09c3bd5ff698_pos1.png сохранено в класс 1
# 100a09c3bd5ff698_pos2.png сохранено в класс 1
# 100a09c3bd5ff698_pos3.png сохранено в класс 1
# 100a09c3bd5ff698_pos4.png сохранено в класс 1
# 100a09c3bd5ff698_pos5.png сохранено в класс 2
# 100a09c3bd5ff698_pos6.png сохранено в класс 2
# 100a09c3bd5ff698_pos7.png не классифицировано, пропускается
# 100a09c3bd5ff698_pos8.png сохранено в класс 1
# 100a09c3bd5ff698_pos9.png сохранено в класс 2
# 10942eb0c5a1bed6_pos1.png сохранено в класс 2
# 10942eb0c5a1bed6_pos2.png сохранено в класс 2
# 10942eb0c5a1bed6_pos3.png сохранено в класс 2
# 10942eb0c5a1bed6_pos4.png сохранено в класс 2
# 10942eb0c5a1bed6_pos5.png сохранено в класс 2
# 10942eb0c5a1bed6_pos6.png сохранено в класс 0
# 10942eb0c5a1bed6_pos7.png не классифицировано, пропускается
# 10942eb0c5a1bed6_pos8.png сохранено в класс 1
# 10942eb0c5a1bed6_pos9.png сохранено в класс 2
# 1111f4e84252e542_pos1.png сохранено в класс 1
# 1111f4e84252e542_pos2.png сохранено в класс 1
# 1111f4e84252e542_pos3.png сохранено в класс 1
# 1111f4e84252e542_pos4.png сохранено в класс 1
# 1111f4e84252e542_pos5.png сохранено в класс 1
# 1111f4e84252e542_pos6.png сохранено в класс 1
# 1111f4e84252e542_pos7.png сохранено в класс 1
# 1111f4e84252e542_pos8.png сохранено в класс 1
# 1111f4e84252e542_pos9.png сохранено в класс 1
# 1193e820021376fd_pos1.png сохранено в класс 1
# 1193e820021376fd_pos2.png сохранено в класс 1
# 1193e820021376fd_pos3.png сохранено в класс 2
# 1193e820021376fd_pos4.png сохранено в класс 1
# 1193e820021376fd_pos5.png сохранено в класс 2
# 1193e820021376fd_pos6.png сохранено в класс 1
# 1193e820021376fd_pos7.png не классифицировано, пропускается
# 1193e820021376fd_pos8.png сохранено в класс 1
# 1193e820021376fd_pos9.png сохранено в класс 1
# 11af2626c8565b79_pos1.png сохранено в класс 0
# 11af2626c8565b79_pos2.png сохранено в класс 0
# 11af2626c8565b79_pos3.png сохранено в класс 0
# 11af2626c8565b79_pos4.png сохранено в класс 0
# 11af2626c8565b79_pos5.png сохранено в класс 0
# 11af2626c8565b79_pos6.png сохранено в класс 0
# 11af2626c8565b79_pos7.png сохранено в класс 0
# 11af2626c8565b79_pos8.png сохранено в класс 2
# 11e0fa8375a9a080_pos1.png не классифицировано, пропускается
# 11e0fa8375a9a080_pos2.png сохранено в класс 0
# 11e0fa8375a9a080_pos3.png сохранено в класс 0
# 11e0fa8375a9a080_pos4.png сохранено в класс 0
# 11e0fa8375a9a080_pos5.png не классифицировано, пропускается
# 11e0fa8375a9a080_pos6.png не классифицировано, пропускается
# 11e0fa8375a9a080_pos7.png не классифицировано, пропускается
# 11e0fa8375a9a080_pos8.png сохранено в класс 2
# 1200b41f305880e2_pos1.png сохранено в класс 1
# 1200b41f305880e2_pos2.png сохранено в класс 1
# 1200b41f305880e2_pos3.png сохранено в класс 1
# 1200b41f305880e2_pos4.png сохранено в класс 1
# 1200b41f305880e2_pos5.png сохранено в класс 1
# 1200b41f305880e2_pos6.png сохранено в класс 1
# 1200b41f305880e2_pos7.png сохранено в класс 1
# 1200b41f305880e2_pos8.png сохранено в класс 2
# 120274b3fb638811_pos1.png сохранено в класс 1
# 120274b3fb638811_pos2.png сохранено в класс 1
# 120274b3fb638811_pos3.png сохранено в класс 1
# 120274b3fb638811_pos4.png сохранено в класс 1
# 120274b3fb638811_pos5.png сохранено в класс 1
# 120274b3fb638811_pos6.png сохранено в класс 1
# 120274b3fb638811_pos7.png сохранено в класс 1
# 120274b3fb638811_pos8.png сохранено в класс 1
# 120274b3fb638811_pos9.png сохранено в класс 1
# 121a02f330542cb6_pos1.png сохранено в класс 1
# 121a02f330542cb6_pos2.png сохранено в класс 2
# 121a02f330542cb6_pos3.png сохранено в класс 2
# 121a02f330542cb6_pos4.png сохранено в класс 2
# 121a02f330542cb6_pos5.png сохранено в класс 2
# 121a02f330542cb6_pos6.png сохранено в класс 0
# 121a02f330542cb6_pos7.png сохранено в класс 2
# 121a02f330542cb6_pos8.png сохранено в класс 1
# 121a02f330542cb6_pos9.png сохранено в класс 1
# 126044a7b0d8a668_pos1.png сохранено в класс 2
# 126044a7b0d8a668_pos2.png сохранено в класс 2
# 126044a7b0d8a668_pos3.png сохранено в класс 2
# 126044a7b0d8a668_pos4.png сохранено в класс 0
# 126044a7b0d8a668_pos5.png сохранено в класс 2
# 126044a7b0d8a668_pos6.png сохранено в класс 0
# 126044a7b0d8a668_pos7.png сохранено в класс 2
# 126044a7b0d8a668_pos8.png сохранено в класс 2
# 126044a7b0d8a668_pos9.png сохранено в класс 1
# 127dc1b66e2ab6a6_pos1.png сохранено в класс 1
# 127dc1b66e2ab6a6_pos2.png сохранено в класс 1
# 127dc1b66e2ab6a6_pos3.png сохранено в класс 1
# 127dc1b66e2ab6a6_pos4.png сохранено в класс 1
# 127dc1b66e2ab6a6_pos5.png сохранено в класс 1
# 127dc1b66e2ab6a6_pos6.png сохранено в класс 1
# 127dc1b66e2ab6a6_pos7.png сохранено в класс 1
# 127dc1b66e2ab6a6_pos8.png сохранено в класс 1
# 127dc1b66e2ab6a6_pos9.png сохранено в класс 1
# 12842f7b1f3080ac_pos1.png сохранено в класс 1
# 12842f7b1f3080ac_pos2.png сохранено в класс 1
# 12842f7b1f3080ac_pos3.png сохранено в класс 1
# 12842f7b1f3080ac_pos4.png сохранено в класс 1
# 12842f7b1f3080ac_pos5.png сохранено в класс 1
# 12842f7b1f3080ac_pos6.png сохранено в класс 1
# 12842f7b1f3080ac_pos7.png сохранено в класс 1
# 12842f7b1f3080ac_pos8.png сохранено в класс 1
# 129d0ab182f6e98a_pos1.png сохранено в класс 1
# 129d0ab182f6e98a_pos2.png сохранено в класс 0
# 129d0ab182f6e98a_pos3.png сохранено в класс 1
# 129d0ab182f6e98a_pos4.png сохранено в класс 1
# 129d0ab182f6e98a_pos5.png сохранено в класс 0
# 129d0ab182f6e98a_pos6.png сохранено в класс 0
# 129d0ab182f6e98a_pos7.png сохранено в класс 0
# 129d0ab182f6e98a_pos8.png сохранено в класс 0
# 130d5dd44c5ada70_pos1.png сохранено в класс 1
# 130d5dd44c5ada70_pos2.png сохранено в класс 0
# 130d5dd44c5ada70_pos3.png сохранено в класс 2
# 130d5dd44c5ada70_pos4.png сохранено в класс 2
# 130d5dd44c5ada70_pos5.png сохранено в класс 2
# 130d5dd44c5ada70_pos6.png сохранено в класс 0
# 130d5dd44c5ada70_pos7.png сохранено в класс 2
# 130d5dd44c5ada70_pos8.png сохранено в класс 2
# 133668583672b4ae_pos1.png сохранено в класс 1
# 133668583672b4ae_pos2.png сохранено в класс 0
# 133668583672b4ae_pos3.png сохранено в класс 0
# 133668583672b4ae_pos4.png сохранено в класс 0
# 133668583672b4ae_pos5.png сохранено в класс 2
# 133668583672b4ae_pos6.png сохранено в класс 0
# 133668583672b4ae_pos7.png сохранено в класс 2
# 133668583672b4ae_pos8.png сохранено в класс 2
# 13e7ff4b0977925c_pos1.png сохранено в класс 1
# 13e7ff4b0977925c_pos2.png сохранено в класс 1
# 13e7ff4b0977925c_pos3.png сохранено в класс 1
# 13e7ff4b0977925c_pos4.png сохранено в класс 1
# 13e7ff4b0977925c_pos5.png сохранено в класс 1
# 13e7ff4b0977925c_pos6.png сохранено в класс 1
# 13e7ff4b0977925c_pos7.png сохранено в класс 1
# 13e7ff4b0977925c_pos8.png сохранено в класс 1
# 13f0f9e5ef2c6ef5_pos1.png сохранено в класс 1
# 13f0f9e5ef2c6ef5_pos2.png сохранено в класс 2
# 13f0f9e5ef2c6ef5_pos3.png сохранено в класс 2
# 13f0f9e5ef2c6ef5_pos4.png сохранено в класс 2
# 13f0f9e5ef2c6ef5_pos5.png сохранено в класс 2
# 13f0f9e5ef2c6ef5_pos6.png сохранено в класс 2
# 13f0f9e5ef2c6ef5_pos7.png не классифицировано, пропускается
# 13f0f9e5ef2c6ef5_pos8.png сохранено в класс 0
# 13f0f9e5ef2c6ef5_pos9.png сохранено в класс 0
# 13f800cf5cf5aec3_pos1.png сохранено в класс 1
# 13f800cf5cf5aec3_pos2.png сохранено в класс 1
# 13f800cf5cf5aec3_pos3.png сохранено в класс 1
# 13f800cf5cf5aec3_pos4.png сохранено в класс 1
# 13f800cf5cf5aec3_pos5.png сохранено в класс 2
# 13f800cf5cf5aec3_pos6.png сохранено в класс 2
# 13f800cf5cf5aec3_pos7.png сохранено в класс 2
# 13f800cf5cf5aec3_pos8.png сохранено в класс 2
# 13f800cf5cf5aec3_pos9.png сохранено в класс 2
# 13fd23fc2feceef4_pos1.png сохранено в класс 1
# 13fd23fc2feceef4_pos2.png сохранено в класс 1
# 13fd23fc2feceef4_pos3.png сохранено в класс 1
# 13fd23fc2feceef4_pos4.png сохранено в класс 1
# 13fd23fc2feceef4_pos5.png сохранено в класс 1
# 13fd23fc2feceef4_pos6.png сохранено в класс 1
# 13fd23fc2feceef4_pos7.png сохранено в класс 1
# 13fd23fc2feceef4_pos8.png сохранено в класс 1
# 140a4d756cd98ae2_pos1.png сохранено в класс 1
# 140a4d756cd98ae2_pos2.png сохранено в класс 1
# 140a4d756cd98ae2_pos3.png сохранено в класс 1
# 140a4d756cd98ae2_pos4.png сохранено в класс 1
# 140a4d756cd98ae2_pos5.png сохранено в класс 1
# 140a4d756cd98ae2_pos6.png сохранено в класс 1
# 140a4d756cd98ae2_pos7.png сохранено в класс 1
# 140a4d756cd98ae2_pos8.png сохранено в класс 1
# 1434c026ca53115c_pos1.png сохранено в класс 1
# 1434c026ca53115c_pos2.png сохранено в класс 1
# 1434c026ca53115c_pos3.png сохранено в класс 1
# 1434c026ca53115c_pos4.png сохранено в класс 1
# 1434c026ca53115c_pos5.png сохранено в класс 1
# 1434c026ca53115c_pos6.png сохранено в класс 1
# 1434c026ca53115c_pos7.png сохранено в класс 1
# 1434c026ca53115c_pos8.png сохранено в класс 1
# 1434c026ca53115c_pos9.png сохранено в класс 2
# 148dd899509acc4b_pos1.png сохранено в класс 1
# 148dd899509acc4b_pos2.png сохранено в класс 1
# 148dd899509acc4b_pos3.png сохранено в класс 1
# 148dd899509acc4b_pos4.png сохранено в класс 1
# 148dd899509acc4b_pos5.png сохранено в класс 1
# 148dd899509acc4b_pos6.png сохранено в класс 1
# 148dd899509acc4b_pos7.png не классифицировано, пропускается
# 148dd899509acc4b_pos8.png сохранено в класс 1
# 14d08b85ce37009c_pos1.png сохранено в класс 0
# 14d08b85ce37009c_pos2.png сохранено в класс 1
# 14d08b85ce37009c_pos3.png сохранено в класс 0
# 14d08b85ce37009c_pos4.png сохранено в класс 1
# 14d08b85ce37009c_pos5.png сохранено в класс 1
# 14d08b85ce37009c_pos6.png сохранено в класс 1
# 14d08b85ce37009c_pos7.png сохранено в класс 1
# 14d08b85ce37009c_pos8.png сохранено в класс 2
# 14d08b85ce37009c_pos9.png сохранено в класс 2
# 14d8f6c49cf43766_pos1.png сохранено в класс 1
# 14d8f6c49cf43766_pos2.png сохранено в класс 1
# 14d8f6c49cf43766_pos3.png сохранено в класс 1
# 14d8f6c49cf43766_pos4.png сохранено в класс 1
# 14d8f6c49cf43766_pos5.png сохранено в класс 2
# 14d8f6c49cf43766_pos6.png сохранено в класс 1
# 14d8f6c49cf43766_pos7.png сохранено в класс 2
# 14d8f6c49cf43766_pos8.png сохранено в класс 2
# 14d8f6c49cf43766_pos9.png сохранено в класс 2
# 14ffbe8779a8fcb9_pos1.png сохранено в класс 0
# 14ffbe8779a8fcb9_pos2.png сохранено в класс 0
# 14ffbe8779a8fcb9_pos3.png сохранено в класс 0
# 14ffbe8779a8fcb9_pos4.png сохранено в класс 0
# 14ffbe8779a8fcb9_pos5.png сохранено в класс 0
# 14ffbe8779a8fcb9_pos6.png сохранено в класс 1
# 14ffbe8779a8fcb9_pos7.png сохранено в класс 1
# 14ffbe8779a8fcb9_pos8.png сохранено в класс 1
# 14ffbe8779a8fcb9_pos9.png сохранено в класс 1
# 1522387ab0c141ab_pos1.png сохранено в класс 1
# 1522387ab0c141ab_pos2.png сохранено в класс 1
# 1522387ab0c141ab_pos3.png сохранено в класс 1
# 1522387ab0c141ab_pos4.png сохранено в класс 1
# 1522387ab0c141ab_pos5.png сохранено в класс 1
# 1522387ab0c141ab_pos6.png сохранено в класс 1
# 1522387ab0c141ab_pos7.png сохранено в класс 2
# 1522387ab0c141ab_pos8.png сохранено в класс 2
# 1522387ab0c141ab_pos9.png сохранено в класс 1
# 153a9ec5b6b26af7_pos1.png сохранено в класс 1
# 153a9ec5b6b26af7_pos2.png сохранено в класс 1
# 153a9ec5b6b26af7_pos3.png сохранено в класс 1
# 153a9ec5b6b26af7_pos4.png сохранено в класс 1
# 153a9ec5b6b26af7_pos5.png сохранено в класс 1
# 153a9ec5b6b26af7_pos6.png сохранено в класс 1
# 153a9ec5b6b26af7_pos7.png сохранено в класс 1
# 153a9ec5b6b26af7_pos8.png сохранено в класс 1
# 153a9ec5b6b26af7_pos9.png сохранено в класс 2
# 15819398c612b797_pos1.png сохранено в класс 0
# 15819398c612b797_pos2.png сохранено в класс 0
# 15819398c612b797_pos3.png сохранено в класс 0
# 15819398c612b797_pos4.png сохранено в класс 0
# 15819398c612b797_pos5.png сохранено в класс 0
# 15819398c612b797_pos6.png сохранено в класс 0
# 15819398c612b797_pos7.png сохранено в класс 2
# 15819398c612b797_pos8.png сохранено в класс 2
# 15ad6e20cb66d6e6_pos1.png сохранено в класс 1
# 15ad6e20cb66d6e6_pos2.png сохранено в класс 1
# 15ad6e20cb66d6e6_pos3.png сохранено в класс 1
# 15ad6e20cb66d6e6_pos4.png сохранено в класс 1
# 15ad6e20cb66d6e6_pos5.png сохранено в класс 1
# 15ad6e20cb66d6e6_pos6.png сохранено в класс 1
# 15ad6e20cb66d6e6_pos7.png сохранено в класс 1
# 15ad6e20cb66d6e6_pos8.png сохранено в класс 1
# 15ad6e20cb66d6e6_pos9.png сохранено в класс 1
# 162cc8e4d82925d7_pos1.png сохранено в класс 1
# 162cc8e4d82925d7_pos2.png сохранено в класс 1
# 162cc8e4d82925d7_pos3.png сохранено в класс 1
# 162cc8e4d82925d7_pos4.png сохранено в класс 0
# 162cc8e4d82925d7_pos5.png сохранено в класс 0
# 162cc8e4d82925d7_pos6.png сохранено в класс 0
# 162cc8e4d82925d7_pos7.png сохранено в класс 0
# 162cc8e4d82925d7_pos8.png сохранено в класс 1
# 1650dd4eda8b6f26_pos1.png сохранено в класс 1
# 1650dd4eda8b6f26_pos2.png сохранено в класс 1
# 1650dd4eda8b6f26_pos3.png сохранено в класс 1
# 1650dd4eda8b6f26_pos4.png сохранено в класс 0
# 1650dd4eda8b6f26_pos5.png сохранено в класс 1
# 1650dd4eda8b6f26_pos6.png сохранено в класс 1
# 1650dd4eda8b6f26_pos7.png сохранено в класс 1
# 1650dd4eda8b6f26_pos8.png сохранено в класс 1
# 1650dd4eda8b6f26_pos9.png сохранено в класс 1
# 165a07cdd0a0aac5_pos1.png сохранено в класс 1
# 165a07cdd0a0aac5_pos2.png сохранено в класс 1
# 165a07cdd0a0aac5_pos3.png сохранено в класс 1
# 165a07cdd0a0aac5_pos4.png сохранено в класс 1
# 165a07cdd0a0aac5_pos5.png сохранено в класс 1
# 165a07cdd0a0aac5_pos6.png сохранено в класс 1
# 165a07cdd0a0aac5_pos7.png сохранено в класс 1
# 165a07cdd0a0aac5_pos8.png сохранено в класс 1
# 165f503a322dcf38_pos1.png сохранено в класс 1
# 165f503a322dcf38_pos2.png сохранено в класс 1
# 165f503a322dcf38_pos3.png сохранено в класс 1
# 165f503a322dcf38_pos4.png сохранено в класс 1
# 165f503a322dcf38_pos5.png сохранено в класс 1
# 165f503a322dcf38_pos6.png сохранено в класс 1
# 165f503a322dcf38_pos7.png сохранено в класс 1
# 165f503a322dcf38_pos8.png сохранено в класс 1
# 165f503a322dcf38_pos9.png сохранено в класс 1
# 17be2727f458112d_pos1.png сохранено в класс 0
# 17be2727f458112d_pos2.png сохранено в класс 0
# 17be2727f458112d_pos3.png сохранено в класс 0
# 17be2727f458112d_pos4.png сохранено в класс 0
# 17be2727f458112d_pos5.png сохранено в класс 0
# 17be2727f458112d_pos6.png сохранено в класс 0
# 17be2727f458112d_pos7.png сохранено в класс 2
# 17be2727f458112d_pos8.png сохранено в класс 2
# 17c95d8e2d1dafd2_pos1.png сохранено в класс 1
# 17c95d8e2d1dafd2_pos2.png сохранено в класс 1
# 17c95d8e2d1dafd2_pos3.png сохранено в класс 1
# 17c95d8e2d1dafd2_pos4.png сохранено в класс 1
# 17c95d8e2d1dafd2_pos5.png сохранено в класс 1
# 17c95d8e2d1dafd2_pos6.png сохранено в класс 1
# 17c95d8e2d1dafd2_pos7.png сохранено в класс 1
# 17c95d8e2d1dafd2_pos8.png сохранено в класс 1
# 17c95d8e2d1dafd2_pos9.png сохранено в класс 1
# 18564b1aea563220_pos1.png сохранено в класс 1
# 18564b1aea563220_pos2.png сохранено в класс 1
# 18564b1aea563220_pos3.png сохранено в класс 1
# 18564b1aea563220_pos4.png сохранено в класс 1
# 18564b1aea563220_pos5.png сохранено в класс 1
# 18564b1aea563220_pos6.png сохранено в класс 1
# 18564b1aea563220_pos7.png сохранено в класс 1
# 18564b1aea563220_pos8.png сохранено в класс 1
# 18564b1aea563220_pos9.png сохранено в класс 1
# 18976db1462ba9f4_pos1.png сохранено в класс 1
# 18976db1462ba9f4_pos2.png сохранено в класс 1
# 18976db1462ba9f4_pos3.png сохранено в класс 1
# 18976db1462ba9f4_pos4.png сохранено в класс 1
# 18976db1462ba9f4_pos5.png сохранено в класс 1
# 18976db1462ba9f4_pos6.png сохранено в класс 1
# 18976db1462ba9f4_pos7.png сохранено в класс 2
# 18976db1462ba9f4_pos8.png сохранено в класс 2
# 18976db1462ba9f4_pos9.png сохранено в класс 2
# 18f4c43170edac4a_pos1.png не классифицировано, пропускается
# 18f4c43170edac4a_pos2.png сохранено в класс 1
# 18f4c43170edac4a_pos3.png сохранено в класс 0
# 18f4c43170edac4a_pos4.png сохранено в класс 0
# 18f4c43170edac4a_pos5.png сохранено в класс 1
# 18f4c43170edac4a_pos6.png сохранено в класс 1
# 18f4c43170edac4a_pos7.png не классифицировано, пропускается
# 18f4c43170edac4a_pos8.png сохранено в класс 0
# 18f4c43170edac4a_pos9.png не классифицировано, пропускается
# 1900b06e63f72964_pos1.png сохранено в класс 1
# 1900b06e63f72964_pos2.png сохранено в класс 1
# 1900b06e63f72964_pos3.png сохранено в класс 1
# 1900b06e63f72964_pos4.png сохранено в класс 1
# 1900b06e63f72964_pos5.png сохранено в класс 1
# 1900b06e63f72964_pos6.png сохранено в класс 2
# 1900b06e63f72964_pos7.png сохранено в класс 2
# 1900b06e63f72964_pos8.png сохранено в класс 2
# 1900b06e63f72964_pos9.png сохранено в класс 2
# 19279dfed319100f_pos1.png сохранено в класс 0
# 19279dfed319100f_pos2.png сохранено в класс 0
# 19279dfed319100f_pos3.png сохранено в класс 2
# 19279dfed319100f_pos4.png сохранено в класс 2
# 19279dfed319100f_pos5.png сохранено в класс 2
# 19279dfed319100f_pos6.png сохранено в класс 0
# 19279dfed319100f_pos7.png сохранено в класс 2
# 19279dfed319100f_pos8.png сохранено в класс 2
# 196394e57850da4b_pos1.png сохранено в класс 1
# 196394e57850da4b_pos2.png сохранено в класс 2
# 196394e57850da4b_pos3.png сохранено в класс 2
# 196394e57850da4b_pos4.png сохранено в класс 2
# 196394e57850da4b_pos5.png сохранено в класс 2
# 196394e57850da4b_pos6.png сохранено в класс 0
# 196394e57850da4b_pos7.png не классифицировано, пропускается
# 196394e57850da4b_pos8.png сохранено в класс 1
# 196394e57850da4b_pos9.png сохранено в класс 1
# 1966f5a348f63b0e_pos1.png сохранено в класс 1
# 1966f5a348f63b0e_pos2.png не классифицировано, пропускается
# 1966f5a348f63b0e_pos3.png сохранено в класс 1
# 1966f5a348f63b0e_pos4.png сохранено в класс 1
# 1966f5a348f63b0e_pos5.png сохранено в класс 1
# 1966f5a348f63b0e_pos6.png сохранено в класс 1
# 1966f5a348f63b0e_pos7.png сохранено в класс 2
# 1966f5a348f63b0e_pos8.png сохранено в класс 2
# 1a19cd008b0bde6c_pos1.png сохранено в класс 1
# 1a19cd008b0bde6c_pos2.png сохранено в класс 1
# 1a19cd008b0bde6c_pos3.png сохранено в класс 1
# 1a19cd008b0bde6c_pos4.png сохранено в класс 1
# 1a19cd008b0bde6c_pos5.png сохранено в класс 1
# 1a19cd008b0bde6c_pos6.png сохранено в класс 1
# 1a19cd008b0bde6c_pos7.png сохранено в класс 1
# 1a19cd008b0bde6c_pos8.png сохранено в класс 1
# 1a19cd008b0bde6c_pos9.png сохранено в класс 1
# 1a4dbb73a7ed0db2_pos1.png сохранено в класс 1
# 1a4dbb73a7ed0db2_pos2.png сохранено в класс 1
# 1a4dbb73a7ed0db2_pos3.png сохранено в класс 2
# 1a4dbb73a7ed0db2_pos4.png сохранено в класс 2
# 1a4dbb73a7ed0db2_pos5.png сохранено в класс 2
# 1a4dbb73a7ed0db2_pos6.png сохранено в класс 2
# 1a4dbb73a7ed0db2_pos7.png не классифицировано, пропускается
# 1a4dbb73a7ed0db2_pos8.png сохранено в класс 1
# 1a4dbb73a7ed0db2_pos9.png сохранено в класс 1
# 1a66cf9a308b1543_pos1.png сохранено в класс 1
# 1a66cf9a308b1543_pos2.png сохранено в класс 2
# 1a66cf9a308b1543_pos3.png сохранено в класс 2
# 1a66cf9a308b1543_pos4.png сохранено в класс 2
# 1a66cf9a308b1543_pos5.png сохранено в класс 2
# 1a66cf9a308b1543_pos6.png сохранено в класс 0
# 1a66cf9a308b1543_pos7.png не классифицировано, пропускается
# 1a66cf9a308b1543_pos8.png не классифицировано, пропускается
# 1a66cf9a308b1543_pos9.png сохранено в класс 1
# 1a8fd53a448467ad_pos1.png сохранено в класс 1
# 1a8fd53a448467ad_pos2.png сохранено в класс 1
# 1a8fd53a448467ad_pos3.png сохранено в класс 1
# 1a8fd53a448467ad_pos4.png сохранено в класс 2
# 1a8fd53a448467ad_pos5.png сохранено в класс 2
# 1a8fd53a448467ad_pos6.png сохранено в класс 2
# 1a8fd53a448467ad_pos7.png сохранено в класс 2
# 1a8fd53a448467ad_pos8.png сохранено в класс 2
# 1aa34cdedfc05e54_pos1.png сохранено в класс 1
# 1aa34cdedfc05e54_pos2.png сохранено в класс 2
# 1aa34cdedfc05e54_pos3.png сохранено в класс 2
# 1aa34cdedfc05e54_pos4.png сохранено в класс 2
# 1aa34cdedfc05e54_pos5.png сохранено в класс 2
# 1aa34cdedfc05e54_pos6.png сохранено в класс 2
# 1aa34cdedfc05e54_pos7.png не классифицировано, пропускается
# 1aa34cdedfc05e54_pos8.png сохранено в класс 1
# 1aa34cdedfc05e54_pos9.png сохранено в класс 1
# 1aa3679f116fbb03_pos1.png сохранено в класс 1
# 1aa3679f116fbb03_pos2.png сохранено в класс 0
# 1aa3679f116fbb03_pos3.png сохранено в класс 0
# 1aa3679f116fbb03_pos4.png сохранено в класс 1
# 1aa3679f116fbb03_pos5.png сохранено в класс 0
# 1aa3679f116fbb03_pos6.png сохранено в класс 0
# 1aa3679f116fbb03_pos7.png не классифицировано, пропускается
# 1aa3679f116fbb03_pos8.png сохранено в класс 1
# 1aa3679f116fbb03_pos9.png сохранено в класс 2
# 1ab4d2583fcaba49_pos1.png сохранено в класс 1
# 1ab4d2583fcaba49_pos2.png сохранено в класс 1
# 1ab4d2583fcaba49_pos3.png сохранено в класс 1
# 1ab4d2583fcaba49_pos4.png сохранено в класс 1
# 1ab4d2583fcaba49_pos5.png сохранено в класс 1
# 1ab4d2583fcaba49_pos6.png сохранено в класс 1
# 1ab4d2583fcaba49_pos7.png сохранено в класс 1
# 1ab4d2583fcaba49_pos8.png сохранено в класс 1
# 1ab4d2583fcaba49_pos9.png сохранено в класс 2
# 1ab911a1e6195422_pos1.png сохранено в класс 1
# 1ab911a1e6195422_pos2.png сохранено в класс 1
# 1ab911a1e6195422_pos3.png сохранено в класс 2
# 1ab911a1e6195422_pos4.png сохранено в класс 2
# 1ab911a1e6195422_pos5.png сохранено в класс 2
# 1ab911a1e6195422_pos6.png сохранено в класс 2
# 1ab911a1e6195422_pos7.png сохранено в класс 2
# 1ab911a1e6195422_pos8.png сохранено в класс 2
# 1ab911a1e6195422_pos9.png сохранено в класс 2
# 1ad3974b10b75bdd_pos1.png сохранено в класс 1
# 1ad3974b10b75bdd_pos2.png сохранено в класс 1
# 1ad3974b10b75bdd_pos3.png сохранено в класс 1
# 1ad3974b10b75bdd_pos4.png сохранено в класс 1
# 1ad3974b10b75bdd_pos5.png сохранено в класс 2
# 1ad3974b10b75bdd_pos6.png сохранено в класс 2
# 1ad3974b10b75bdd_pos7.png сохранено в класс 2
# 1ad3974b10b75bdd_pos8.png сохранено в класс 2
# 1ad3974b10b75bdd_pos9.png сохранено в класс 2
# 1b8168f5a774e4d1_pos1.png сохранено в класс 1
# 1b8168f5a774e4d1_pos2.png сохранено в класс 1
# 1b8168f5a774e4d1_pos3.png сохранено в класс 1
# 1b8168f5a774e4d1_pos4.png сохранено в класс 1
# 1b8168f5a774e4d1_pos5.png сохранено в класс 1
# 1b8168f5a774e4d1_pos6.png сохранено в класс 1
# 1b8168f5a774e4d1_pos7.png сохранено в класс 1
# 1b8168f5a774e4d1_pos8.png сохранено в класс 1
# 1b8168f5a774e4d1_pos9.png сохранено в класс 1
# 1bb3f1743f421a46_pos1.png сохранено в класс 0
# 1bb3f1743f421a46_pos2.png сохранено в класс 0
# 1bb3f1743f421a46_pos3.png сохранено в класс 0
# 1bb3f1743f421a46_pos4.png сохранено в класс 0
# 1bb3f1743f421a46_pos5.png сохранено в класс 0
# 1bb3f1743f421a46_pos6.png сохранено в класс 0
# 1bb3f1743f421a46_pos7.png сохранено в класс 0
# 1bb3f1743f421a46_pos8.png сохранено в класс 0
# 1c003fae26c7f300_pos1.png сохранено в класс 0
# 1c003fae26c7f300_pos2.png сохранено в класс 0
# 1c003fae26c7f300_pos3.png сохранено в класс 0
# 1c003fae26c7f300_pos4.png сохранено в класс 0
# 1c003fae26c7f300_pos5.png сохранено в класс 0
# 1c003fae26c7f300_pos6.png сохранено в класс 0
# 1c003fae26c7f300_pos7.png сохранено в класс 2
# 1c003fae26c7f300_pos8.png сохранено в класс 2
# 1c1534c45d39e267_pos1.png сохранено в класс 1
# 1c1534c45d39e267_pos2.png сохранено в класс 1
# 1c1534c45d39e267_pos3.png сохранено в класс 2
# 1c1534c45d39e267_pos4.png сохранено в класс 2
# 1c1534c45d39e267_pos5.png сохранено в класс 2
# 1c1534c45d39e267_pos6.png сохранено в класс 2
# 1c1534c45d39e267_pos7.png не классифицировано, пропускается
# 1c1534c45d39e267_pos8.png сохранено в класс 1
# 1c1534c45d39e267_pos9.png сохранено в класс 1
# 1c66d2b1e756b3d9_pos1.png сохранено в класс 1
# 1c66d2b1e756b3d9_pos2.png сохранено в класс 1
# 1c66d2b1e756b3d9_pos3.png сохранено в класс 1
# 1c66d2b1e756b3d9_pos4.png сохранено в класс 1
# 1c66d2b1e756b3d9_pos5.png сохранено в класс 1
# 1c66d2b1e756b3d9_pos6.png сохранено в класс 1
# 1c66d2b1e756b3d9_pos7.png сохранено в класс 1
# 1c66d2b1e756b3d9_pos8.png сохранено в класс 1
# 1c8d3ba2ab4e0d82_pos1.png сохранено в класс 1
# 1c8d3ba2ab4e0d82_pos2.png сохранено в класс 1
# 1c8d3ba2ab4e0d82_pos3.png сохранено в класс 2
# 1c8d3ba2ab4e0d82_pos4.png сохранено в класс 2
# 1c8d3ba2ab4e0d82_pos5.png сохранено в класс 2
# 1c8d3ba2ab4e0d82_pos6.png сохранено в класс 0
# 1c8d3ba2ab4e0d82_pos7.png не классифицировано, пропускается
# 1c8d3ba2ab4e0d82_pos8.png сохранено в класс 1
# 1c8d3ba2ab4e0d82_pos9.png сохранено в класс 1
# 1ceb44b17a0671b2_pos1.png сохранено в класс 1
# 1ceb44b17a0671b2_pos2.png сохранено в класс 1
# 1ceb44b17a0671b2_pos3.png сохранено в класс 1
# 1ceb44b17a0671b2_pos4.png сохранено в класс 1
# 1ceb44b17a0671b2_pos5.png сохранено в класс 1
# 1ceb44b17a0671b2_pos6.png сохранено в класс 1
# 1ceb44b17a0671b2_pos7.png сохранено в класс 1
# 1ceb44b17a0671b2_pos8.png сохранено в класс 1
# 1cec09c17a3bb48a_pos1.png сохранено в класс 1
# 1cec09c17a3bb48a_pos2.png сохранено в класс 1
# 1cec09c17a3bb48a_pos3.png сохранено в класс 1
# 1cec09c17a3bb48a_pos4.png сохранено в класс 1
# 1cec09c17a3bb48a_pos5.png сохранено в класс 1
# 1cec09c17a3bb48a_pos6.png сохранено в класс 1
# 1cec09c17a3bb48a_pos7.png не классифицировано, пропускается
# 1cec09c17a3bb48a_pos8.png сохранено в класс 1
# 1cec09c17a3bb48a_pos9.png сохранено в класс 2
# 1d0c87ba2cdf2e09_pos1.png сохранено в класс 1
# 1d0c87ba2cdf2e09_pos2.png сохранено в класс 1
# 1d0c87ba2cdf2e09_pos3.png сохранено в класс 1
# 1d0c87ba2cdf2e09_pos4.png сохранено в класс 1
# 1d0c87ba2cdf2e09_pos5.png сохранено в класс 1
# 1d0c87ba2cdf2e09_pos6.png сохранено в класс 1
# 1d0c87ba2cdf2e09_pos7.png сохранено в класс 1
# 1d0c87ba2cdf2e09_pos8.png сохранено в класс 1
# 1d0c87ba2cdf2e09_pos9.png сохранено в класс 1
# 1d16849753b20612_pos1.png сохранено в класс 0
# 1d16849753b20612_pos2.png сохранено в класс 1
# 1d16849753b20612_pos3.png сохранено в класс 1
# 1d16849753b20612_pos4.png сохранено в класс 1
# 1d16849753b20612_pos5.png сохранено в класс 1
# 1d16849753b20612_pos6.png сохранено в класс 2
# 1d16849753b20612_pos7.png сохранено в класс 2
# 1d16849753b20612_pos8.png сохранено в класс 2
# 1d16849753b20612_pos9.png сохранено в класс 2
# 1d2f67c87c14be71_pos1.png сохранено в класс 1
# 1d2f67c87c14be71_pos2.png сохранено в класс 1
# 1d2f67c87c14be71_pos3.png сохранено в класс 1
# 1d2f67c87c14be71_pos4.png сохранено в класс 1
# 1d2f67c87c14be71_pos5.png сохранено в класс 1
# 1d2f67c87c14be71_pos6.png сохранено в класс 1
# 1d2f67c87c14be71_pos7.png сохранено в класс 1
# 1d2f67c87c14be71_pos8.png сохранено в класс 1
# 1d2f67c87c14be71_pos9.png сохранено в класс 1
# 1d3b00cfd6c20193_pos1.png сохранено в класс 0
# 1d3b00cfd6c20193_pos2.png сохранено в класс 0
# 1d3b00cfd6c20193_pos3.png сохранено в класс 0
# 1d3b00cfd6c20193_pos4.png сохранено в класс 1
# 1d3b00cfd6c20193_pos5.png сохранено в класс 1
# 1d3b00cfd6c20193_pos6.png сохранено в класс 1
# 1d3b00cfd6c20193_pos7.png сохранено в класс 1
# 1d3b00cfd6c20193_pos8.png сохранено в класс 1
# 1d3b00cfd6c20193_pos9.png сохранено в класс 2
# 1d3b5e08df6963dc_pos1.png сохранено в класс 1
# 1d3b5e08df6963dc_pos2.png сохранено в класс 1
# 1d3b5e08df6963dc_pos3.png сохранено в класс 1
# 1d3b5e08df6963dc_pos4.png сохранено в класс 1
# 1d3b5e08df6963dc_pos5.png сохранено в класс 1
# 1d3b5e08df6963dc_pos6.png сохранено в класс 1
# 1d3b5e08df6963dc_pos7.png сохранено в класс 1
# 1d3b5e08df6963dc_pos8.png сохранено в класс 1
# 1d3b5e08df6963dc_pos9.png сохранено в класс 2
# 1ddb130ce6001f94_pos1.png сохранено в класс 1
# 1ddb130ce6001f94_pos2.png сохранено в класс 1
# 1ddb130ce6001f94_pos3.png сохранено в класс 1
# 1ddb130ce6001f94_pos4.png сохранено в класс 1
# 1ddb130ce6001f94_pos5.png сохранено в класс 1
# 1ddb130ce6001f94_pos6.png сохранено в класс 1
# 1ddb130ce6001f94_pos7.png сохранено в класс 1
# 1ddb130ce6001f94_pos8.png сохранено в класс 1
# 1dee9312996d201c_pos1.png сохранено в класс 1
# 1dee9312996d201c_pos2.png сохранено в класс 1
# 1dee9312996d201c_pos3.png сохранено в класс 2
# 1dee9312996d201c_pos4.png сохранено в класс 2
# 1dee9312996d201c_pos5.png сохранено в класс 2
# 1dee9312996d201c_pos6.png сохранено в класс 2
# 1dee9312996d201c_pos7.png не классифицировано, пропускается
# 1dee9312996d201c_pos8.png сохранено в класс 1
# 1dee9312996d201c_pos9.png сохранено в класс 1
# 1e008498bf30f4c7_pos1.png сохранено в класс 1
# 1e008498bf30f4c7_pos2.png сохранено в класс 1
# 1e008498bf30f4c7_pos3.png сохранено в класс 1
# 1e008498bf30f4c7_pos4.png сохранено в класс 1
# 1e008498bf30f4c7_pos5.png сохранено в класс 1
# 1e008498bf30f4c7_pos6.png сохранено в класс 1
# 1e008498bf30f4c7_pos7.png сохранено в класс 1
# 1e008498bf30f4c7_pos8.png сохранено в класс 1
# 1e008498bf30f4c7_pos9.png сохранено в класс 2
# 1e30ec70774de816_pos1.png сохранено в класс 1
# 1e30ec70774de816_pos2.png сохранено в класс 1
# 1e30ec70774de816_pos3.png сохранено в класс 1
# 1e30ec70774de816_pos4.png сохранено в класс 1
# 1e30ec70774de816_pos5.png сохранено в класс 1
# 1e30ec70774de816_pos6.png сохранено в класс 1
# 1e30ec70774de816_pos7.png сохранено в класс 1
# 1e30ec70774de816_pos8.png сохранено в класс 1
# 1e30ec70774de816_pos9.png сохранено в класс 1
# 1e3d8a5ca46f9754_pos1.png сохранено в класс 1
# 1e3d8a5ca46f9754_pos2.png сохранено в класс 1
# 1e3d8a5ca46f9754_pos3.png сохранено в класс 1
# 1e3d8a5ca46f9754_pos4.png сохранено в класс 2
# 1e3d8a5ca46f9754_pos5.png сохранено в класс 2
# 1e3d8a5ca46f9754_pos6.png сохранено в класс 2
# 1e3d8a5ca46f9754_pos7.png не классифицировано, пропускается
# 1e3d8a5ca46f9754_pos8.png сохранено в класс 1
# 1e3d8a5ca46f9754_pos9.png сохранено в класс 1
# 1f39e007f1e57b3b_pos1.png сохранено в класс 1
# 1f39e007f1e57b3b_pos2.png сохранено в класс 1
# 1f39e007f1e57b3b_pos3.png сохранено в класс 1
# 1f39e007f1e57b3b_pos4.png сохранено в класс 1
# 1f39e007f1e57b3b_pos5.png сохранено в класс 1
# 1f39e007f1e57b3b_pos6.png сохранено в класс 2
# 1f39e007f1e57b3b_pos7.png сохранено в класс 2
# 1f39e007f1e57b3b_pos8.png сохранено в класс 0
# 1f39e007f1e57b3b_pos9.png сохранено в класс 1
# 1fe27fb23a33ac6f_pos1.png сохранено в класс 1
# 1fe27fb23a33ac6f_pos2.png сохранено в класс 1
# 1fe27fb23a33ac6f_pos3.png сохранено в класс 1
# 1fe27fb23a33ac6f_pos4.png сохранено в класс 2
# 1fe27fb23a33ac6f_pos5.png сохранено в класс 2
# 1fe27fb23a33ac6f_pos6.png сохранено в класс 2
# 1fe27fb23a33ac6f_pos7.png сохранено в класс 2
# 1fe27fb23a33ac6f_pos8.png сохранено в класс 2
# 1fe27fb23a33ac6f_pos9.png сохранено в класс 2
# 1ffbbc22830e2517_pos1.png сохранено в класс 2
# 1ffbbc22830e2517_pos2.png сохранено в класс 2
# 1ffbbc22830e2517_pos3.png сохранено в класс 2
# 1ffbbc22830e2517_pos4.png сохранено в класс 2
# 1ffbbc22830e2517_pos5.png сохранено в класс 2
# 1ffbbc22830e2517_pos6.png сохранено в класс 2
# 1ffbbc22830e2517_pos7.png сохранено в класс 2
# 1ffbbc22830e2517_pos8.png сохранено в класс 2
# 1ffbbc22830e2517_pos9.png сохранено в класс 1
# 20512a9e9c53bf4d_pos1.png сохранено в класс 1
# 20512a9e9c53bf4d_pos2.png сохранено в класс 1
# 20512a9e9c53bf4d_pos3.png сохранено в класс 1
# 20512a9e9c53bf4d_pos4.png сохранено в класс 1
# 20512a9e9c53bf4d_pos5.png сохранено в класс 1
# 20512a9e9c53bf4d_pos6.png сохранено в класс 1
# 20512a9e9c53bf4d_pos7.png сохранено в класс 1
# 20512a9e9c53bf4d_pos8.png сохранено в класс 1
# 20512a9e9c53bf4d_pos9.png сохранено в класс 2
# 20cd55591acfd081_pos1.png сохранено в класс 1
# 20cd55591acfd081_pos2.png сохранено в класс 1
# 20cd55591acfd081_pos3.png сохранено в класс 1
# 20cd55591acfd081_pos4.png сохранено в класс 1
# 20cd55591acfd081_pos5.png сохранено в класс 1
# 20cd55591acfd081_pos6.png сохранено в класс 1
# 20cd55591acfd081_pos7.png сохранено в класс 2
# 20cd55591acfd081_pos8.png сохранено в класс 2
# 20cd55591acfd081_pos9.png сохранено в класс 2
# 20e08014d4df2bc6_pos1.png сохранено в класс 0
# 20e08014d4df2bc6_pos2.png сохранено в класс 0
# 20e08014d4df2bc6_pos3.png сохранено в класс 0
# 20e08014d4df2bc6_pos4.png сохранено в класс 0
# 20e08014d4df2bc6_pos5.png сохранено в класс 2
# 20e08014d4df2bc6_pos6.png не классифицировано, пропускается
# 20e08014d4df2bc6_pos7.png сохранено в класс 2
# 20e08014d4df2bc6_pos8.png сохранено в класс 2
# 214589a9b309bd35_pos1.png сохранено в класс 1
# 214589a9b309bd35_pos2.png сохранено в класс 0
# 214589a9b309bd35_pos3.png сохранено в класс 0
# 214589a9b309bd35_pos4.png сохранено в класс 0
# 214589a9b309bd35_pos5.png сохранено в класс 0
# 214589a9b309bd35_pos6.png сохранено в класс 0
# 214589a9b309bd35_pos7.png сохранено в класс 2
# 214589a9b309bd35_pos8.png сохранено в класс 2
# 21506a840d523c46_pos1.png сохранено в класс 1
# 21506a840d523c46_pos2.png сохранено в класс 1
# 21506a840d523c46_pos3.png сохранено в класс 1
# 21506a840d523c46_pos4.png сохранено в класс 1
# 21506a840d523c46_pos5.png сохранено в класс 1
# 21506a840d523c46_pos6.png сохранено в класс 2
# 21506a840d523c46_pos7.png сохранено в класс 2
# 21506a840d523c46_pos8.png сохранено в класс 2
# 21506a840d523c46_pos9.png сохранено в класс 2
# 2180e7d52b7a6e3f_pos1.png сохранено в класс 1
# 2180e7d52b7a6e3f_pos2.png сохранено в класс 1
# 2180e7d52b7a6e3f_pos3.png сохранено в класс 1
# 2180e7d52b7a6e3f_pos4.png сохранено в класс 1
# 2180e7d52b7a6e3f_pos5.png сохранено в класс 1
# 2180e7d52b7a6e3f_pos6.png сохранено в класс 1
# 2180e7d52b7a6e3f_pos7.png сохранено в класс 1
# 2180e7d52b7a6e3f_pos8.png сохранено в класс 1
# 21a798c4825e5217_pos1.png сохранено в класс 1
# 21a798c4825e5217_pos2.png сохранено в класс 1
# 21a798c4825e5217_pos3.png сохранено в класс 1
# 21a798c4825e5217_pos4.png сохранено в класс 1
# 21a798c4825e5217_pos5.png сохранено в класс 2
# 21a798c4825e5217_pos6.png сохранено в класс 2
# 21a798c4825e5217_pos7.png сохранено в класс 2
# 21a798c4825e5217_pos8.png сохранено в класс 2
# 21a798c4825e5217_pos9.png сохранено в класс 1
# 21ab7e131e13eaf6_pos1.png сохранено в класс 0
# 21ab7e131e13eaf6_pos2.png сохранено в класс 0
# 21ab7e131e13eaf6_pos3.png сохранено в класс 0
# 21ab7e131e13eaf6_pos4.png сохранено в класс 0
# 21ab7e131e13eaf6_pos5.png сохранено в класс 0
# 21ab7e131e13eaf6_pos6.png сохранено в класс 0
# 21ab7e131e13eaf6_pos7.png сохранено в класс 2
# 21ab7e131e13eaf6_pos8.png сохранено в класс 2
# 21ab7e131e13eaf6_pos9.png сохранено в класс 2
# 21f6d8e94e103cc0_pos1.png сохранено в класс 1
# 21f6d8e94e103cc0_pos2.png сохранено в класс 2
# 21f6d8e94e103cc0_pos3.png сохранено в класс 2
# 21f6d8e94e103cc0_pos4.png сохранено в класс 2
# 21f6d8e94e103cc0_pos5.png сохранено в класс 2
# 21f6d8e94e103cc0_pos6.png сохранено в класс 0
# 21f6d8e94e103cc0_pos7.png не классифицировано, пропускается
# 21f6d8e94e103cc0_pos8.png сохранено в класс 0
# 21f6d8e94e103cc0_pos9.png сохранено в класс 1
# 22106630cefbab0c_pos1.png сохранено в класс 1
# 22106630cefbab0c_pos2.png сохранено в класс 1
# 22106630cefbab0c_pos3.png сохранено в класс 1
# 22106630cefbab0c_pos4.png сохранено в класс 1
# 22106630cefbab0c_pos5.png сохранено в класс 1
# 22106630cefbab0c_pos6.png сохранено в класс 1
# 22106630cefbab0c_pos7.png сохранено в класс 1
# 22106630cefbab0c_pos8.png сохранено в класс 1
# 22106630cefbab0c_pos9.png сохранено в класс 1
# 22b575e9b2dc748e_pos1.png сохранено в класс 0
# 22b575e9b2dc748e_pos2.png сохранено в класс 0
# 22b575e9b2dc748e_pos3.png сохранено в класс 1
# 22b575e9b2dc748e_pos4.png сохранено в класс 1
# 22b575e9b2dc748e_pos5.png сохранено в класс 0
# 22b575e9b2dc748e_pos6.png сохранено в класс 1
# 22b575e9b2dc748e_pos7.png сохранено в класс 1
# 22b575e9b2dc748e_pos8.png сохранено в класс 1
# 22b575e9b2dc748e_pos9.png сохранено в класс 1

# %% [markdown]
# # Код для сохранения символов из трафарета

# %% [markdown]
# ## Использовался для подготовки изображений к обучению сети, предсказывающей положение символа в трафарете

# %%
import cv2
from PIL import Image
import os

def extract_fragments(image_path, template, output_dir):
    # Загрузить изображение
    image = cv2.imread(image_path)
    height, width, _ = image.shape
    print(height, width)
    if height < 100:
        width = int(width * (100 / height))
        height = 100
        
    print(height, width)
    image = cv2.resize(image, (width, height))
    # Убедиться, что директория для сохранения фрагментов существует
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Извлечь фрагменты
    for region in template:
        pos = region['pos']
        p1 = (int(region['p1'][0] * width), int(region['p1'][1] * height))
        p2 = (int(region['p2'][0] * width), int(region['p2'][1] * height))
        
        fragment = image[p1[1]:p2[1], p1[0]:p2[0]]
        
        # Сохранить фрагмент как изображение
        fragment_path = os.path.join(output_dir, f'fragment_{pos}.png')
        cv2.imwrite(fragment_path, fragment)
        print(f"Fragment {pos} saved at {fragment_path}")

# Пример использования
names = os.listdir(r'F:\grozny\beeline\train_borders\align')
image_path = r'F:\grozny\beeline\train_borders\align\\' + names[7]
output_dir = r'F:\grozny\beeline\train_borders\fragments'  # Директория для сохранения фрагментов

two_digit_region_template = [
    {'pos': 1, 'p1': (0.05, 0.250), 'p2': (0.16, 0.92)},
    {'pos': 2, 'p1': (0.16, 0.100), 'p2': (0.27, 0.92)},
    {'pos': 3, 'p1': (0.265, 0.100), 'p2': (0.375, 0.92)},
    {'pos': 4, 'p1': (0.37, 0.100), 'p2': (0.48, 0.92)},
    {'pos': 5, 'p1': (0.475, 0.250), 'p2': (0.585, 0.92)},
    {'pos': 6, 'p1': (0.58, 0.250), 'p2': (0.69, 0.92)},
    {'pos': 7, 'p1': (0.71, 0.05), 'p2': (0.795, 0.7)},
    {'pos': 8, 'p1': (0.79, 0.05), 'p2': (0.875, 0.7)},
    {'pos': 9, 'p1': (0.87, 0.05), 'p2': (0.96, 0.7)}
]

extract_fragments(image_path, two_digit_region_template, output_dir)
# Out:
# 13 65
# 100 500
# Fragment 1 saved at F:\grozny\beeline\train_borders\fragments\fragment_1.png
# Fragment 2 saved at F:\grozny\beeline\train_borders\fragments\fragment_2.png
# Fragment 3 saved at F:\grozny\beeline\train_borders\fragments\fragment_3.png
# Fragment 4 saved at F:\grozny\beeline\train_borders\fragments\fragment_4.png
# Fragment 5 saved at F:\grozny\beeline\train_borders\fragments\fragment_5.png
# Fragment 6 saved at F:\grozny\beeline\train_borders\fragments\fragment_6.png
# Fragment 7 saved at F:\grozny\beeline\train_borders\fragments\fragment_7.png
# Fragment 8 saved at F:\grozny\beeline\train_borders\fragments\fragment_8.png
# Fragment 9 saved at F:\grozny\beeline\train_borders\fragments\fragment_9.png
